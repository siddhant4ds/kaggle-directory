# %% [markdown]
# # Setup

# %% [markdown]
# Installing/upgrading required libraries:

# %%
# %%capture
# !pip install --upgrade pypair
# !pip install --upgrade scikit-learn

# %% [markdown]
# Importing libraries:

# %%
import gc
gc.enable()

import warnings
warnings.filterwarnings('ignore')

import time
import joblib
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from pypair.association import (
    binary_continuous, 
    binary_binary
)
from sklearn.feature_selection import (
    chi2, 
    f_classif, 
    mutual_info_classif
)
from sklearn.metrics import (
    make_scorer,
    f1_score,
    roc_auc_score,
    matthews_corrcoef,
    classification_report,
    confusion_matrix
)
from sklearn.model_selection import (
    train_test_split,
    StratifiedKFold,
    TunedThresholdClassifierCV
)
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import (
    LinearDiscriminantAnalysis,
    QuadraticDiscriminantAnalysis
)
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    RandomForestClassifier,
    ExtraTreesClassifier,
    AdaBoostClassifier,
    VotingClassifier,
    StackingClassifier
)
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

SEED = 2024

# %% [markdown]
# Importing data:

# %%
data = pd.read_csv('/kaggle/input/health-insurance-cross-sell-prediction/train.csv')

# %% [markdown]
# # Data overview

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB

# %% [markdown]
# ### Target

# %%
TARGET = 'Response'
data[TARGET].value_counts(normalize=True)
# Out:
# Response
# 0    0.877437
# 1    0.122563
# Name: proportion, dtype: float64

# %% [markdown]
# * Heavily imbalanced distribution.
# * Instead of focusing on Accuracy score, we will use AUC for evaluating the models.

# %% [markdown]
# ### Missing values

# %%
data.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Duplicate rows

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Without TARGET**: repeated customers

# %%
data.duplicated(subset=[f for f in data.columns if f != TARGET]).sum()
# Out:
# 0

# %% [markdown]
# **Without *id***: similar features with same outcomes

# %%
data.duplicated(subset=[f for f in data.columns if f != 'id']).sum()
# Out:
# 269

# %% [markdown]
# **Without *id* and TARGET**: similar features with same or different outcomes

# %%
data.duplicated(subset=[f for f in data.columns if f not in ('id', TARGET)]).sum()
# Out:
# 322

# %%
duplicates = data.duplicated(subset=[f for f in data.columns if f not in ('id', TARGET)])
data.loc[duplicates][TARGET].value_counts(normalize=True)
# Out:
# Response
# 0    0.84472
# 1    0.15528
# Name: proportion, dtype: float64

# %% [markdown]
# Almost the same distribution as the dataset.
# We can remove duplicates without affecting the class ratio.

# %%
data = data.drop_duplicates(
    subset=[f for f in data.columns if f not in ('id', TARGET)], 
    ignore_index=True,
    keep='first'
)

# %%
data[TARGET].value_counts(normalize=True)
# Out:
# Response
# 0    0.877464
# 1    0.122536
# Name: proportion, dtype: float64

# %% [markdown]
# Class ratio maintained.

# %% [markdown]
# # Feature exploration & preprocessing

# %% [markdown]
# ### id

# %%
data.shape[0], data.id.nunique()
# Out:
# (380787, 380787)

# %% [markdown]
# We can drop the unique identifier from our feature set.

# %% [markdown]
# ### Gender

# %%
data.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data.Gender.value_counts(normalize=True)
# Out:
# Gender
# Male      0.540743
# Female    0.459257
# Name: proportion, dtype: float64

# %% [markdown]
# Balanced distribution.

# %%
data.groupby('Gender')[TARGET].value_counts(normalize=True)
# Out:
# Gender  Response
# Female  0           0.896140
#         1           0.103860
# Male    0           0.861603
#         1           0.138397
# Name: proportion, dtype: float64

# %% [markdown]
# Slight difference in splits. Will need statistical tests to determine significance.

# %%
data['Gender'] = data.Gender.replace({'Female': 0, 'Male': 1})

# %% [markdown]
# ### Age

# %%
data.Age.describe()
# Out:
# count    380787.000000
# mean         38.822951
# std          15.513783
# min          20.000000
# 25%          25.000000
# 50%          36.000000
# 75%          49.000000
# max          85.000000
# Name: Age, dtype: float64

# %%
def plot_numerical(f, dataset=data):
    fig, ax = plt.subplots(1, 2, figsize=(14, 4))
    plt.suptitle(f'{f}')
    ax[0].set_title('Feature distribution split by target')
    sns.kdeplot(data=dataset, x=f, hue=TARGET, cut=0, bw_adjust=1.5, ax=ax[0])
    ax[1].set_title('Feature distribution for positive class')
    sns.kdeplot(data=dataset[dataset[TARGET]==1], x=f, cut=0, bw_adjust=1.5, ax=ax[1])
    fig.tight_layout()
    plt.show()

# %%
plot_numerical('Age')

# %% [markdown]
# The distribution shows some differences when split by target.
# This feature is a candidate for discretizing.

# %%
data.query("Age <= 27")[TARGET].value_counts(normalize=True), data.query("Age > 27")[TARGET].value_counts(normalize=True)
# Out:
# (Response
#  0    0.96395
#  1    0.03605
#  Name: proportion, dtype: float64,
#  Response
#  0    0.827915
#  1    0.172085
#  Name: proportion, dtype: float64)

# %% [markdown]
# ### Driving_License

# %%
data.Driving_License.unique()
# Out:
# array([1, 0])

# %%
data.Driving_License.value_counts(normalize=True)
# Out:
# Driving_License
# 1    0.997868
# 0    0.002132
# Name: proportion, dtype: float64

# %% [markdown]
# Extremely imbalanced feature -> low variance.
# Might not be very informative on its own.

# %%
data.groupby('Driving_License')[TARGET].value_counts(normalize=True)
# Out:
# Driving_License  Response
# 0                0           0.949507
#                  1           0.050493
# 1                0           0.877310
#                  1           0.122690
# Name: proportion, dtype: float64

# %%
data.groupby('Driving_License')['Age'].describe()
# Out:
#                     count       mean        std   min    25%   50%   75%   max
# Driving_License
# 0                   812.0  65.604680  10.479509  21.0  59.75  67.0  74.0  85.0
# 1                379975.0  38.765719  15.473246  20.0  25.00  36.0  49.0  85.0

# %% [markdown]
# People without a driving license are mostly older (beyond retirement age), making them less likely to be interested in vehicle insurance.

# %% [markdown]
# ### Region_Code

# %%
data.Region_Code.nunique()
# Out:
# 53

# %%
data.Region_Code.unique()[:10]
# Out:
# array([28.,  3., 11., 41., 33.,  6., 35., 50., 15., 45.])

# %% [markdown]
# We can treat this feature as numerical for modeling purposes.

# %%
data.groupby('Region_Code')[TARGET].value_counts()[:10]
# Out:
# Region_Code  Response
# 0.0          0           1840
#              1            174
# 1.0          0            897
#              1            109
# 2.0          0           3750
#              1            287
# 3.0          0           8064
#              1           1179
# 4.0          0           1513
#              1            285
# Name: count, dtype: int64

# %%
plot_numerical('Region_Code')

# %% [markdown]
# ### Previously_Insured

# %%
data.Previously_Insured.unique()
# Out:
# array([0, 1])

# %%
data.Previously_Insured.value_counts(normalize=True)
# Out:
# Previously_Insured
# 0    0.541728
# 1    0.458272
# Name: proportion, dtype: float64

# %%
data.groupby('Previously_Insured')[TARGET].value_counts(normalize=True)
# Out:
# Previously_Insured  Response
# 0                   0           0.774572
#                     1           0.225428
# 1                   0           0.999095
#                     1           0.000905
# Name: proportion, dtype: float64

# %% [markdown]
# Very strong indicator based on target splits.

# %% [markdown]
# ### Vehicle_Age

# %%
data.Vehicle_Age.unique()
# Out:
# array(['> 2 Years', '1-2 Year', '< 1 Year'], dtype=object)

# %%
data.Vehicle_Age.value_counts(normalize=True)
# Out:
# Vehicle_Age
# 1-2 Year     0.525546
# < 1 Year     0.432433
# > 2 Years    0.042021
# Name: proportion, dtype: float64

# %%
data.groupby('Vehicle_Age')[TARGET].value_counts(normalize=True)
# Out:
# Vehicle_Age  Response
# 1-2 Year     0           0.826295
#              1           0.173705
# < 1 Year     0           0.956287
#              1           0.043713
# > 2 Years    0           0.706268
#              1           0.293732
# Name: proportion, dtype: float64

# %% [markdown]
# * Ordinal relation between the categories.
# * Target splits show an ordinal relation too -> Can be a numerical feature for some models.

# %%
data['Vehicle_Age'] = data.Vehicle_Age.replace({'< 1 Year': 0, '1-2 Year': 1, '> 2 Years': 2})

# %% [markdown]
# ### Vehicle_Damage

# %%
data.Vehicle_Damage.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data.Vehicle_Damage.value_counts(normalize=True)
# Out:
# Vehicle_Damage
# Yes    0.504807
# No     0.495193
# Name: proportion, dtype: float64

# %%
data.groupby('Vehicle_Damage')[TARGET].value_counts(normalize=True)
# Out:
# Vehicle_Damage  Response
# No              0           0.994792
#                 1           0.005208
# Yes             0           0.762371
#                 1           0.237629
# Name: proportion, dtype: float64

# %% [markdown]
# Strong indicator based on target-based split.

# %%
data['Vehicle_Damage'] = data.Vehicle_Damage.replace({'No': 0, 'Yes': 1})

# %% [markdown]
# ### Annual_Premium

# %%
data.Annual_Premium.describe()
# Out:
# count    380787.000000
# mean      30587.906869
# std       17201.294205
# min        2630.000000
# 25%       24430.000000
# 50%       31680.000000
# 75%       39409.000000
# max      540165.000000
# Name: Annual_Premium, dtype: float64

# %%
plot_numerical('Annual_Premium')

# %%
plot_numerical('Annual_Premium', data.query("Annual_Premium < 2e4"))

# %%
plot_numerical('Annual_Premium', data.query("2e4 < Annual_Premium < 5e4"))

# %%
plot_numerical('Annual_Premium', data.query("5e4 < Annual_Premium < 1e5"))

# %% [markdown]
# ### Policy_Sales_Channel

# %%
data.Policy_Sales_Channel.nunique()
# Out:
# 155

# %%
data.Policy_Sales_Channel.unique()[:10]
# Out:
# array([ 26., 152., 160., 124.,  14.,  13.,  30., 156., 163., 157.])

# %% [markdown]
# Again, a categorical feature with high-cardinality, which can be treated like a numerical feature.

# %%
plot_numerical('Policy_Sales_Channel')

# %% [markdown]
# ### Vintage

# %%
data.Vintage.describe()
# Out:
# count    380787.000000
# mean        154.344844
# std          83.669560
# min          10.000000
# 25%          82.000000
# 50%         154.000000
# 75%         227.000000
# max         299.000000
# Name: Vintage, dtype: float64

# %%
plot_numerical('Vintage')

# %% [markdown]
# Uniform distribution and no target-based splits.

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ### age_group

# %%
data['age_group'] = (data['Age'] > 27).astype('int')

# %%
data.age_group.value_counts(normalize=True)
# Out:
# age_group
# 1    0.635762
# 0    0.364238
# Name: proportion, dtype: float64

# %%
data.groupby('age_group')[TARGET].value_counts(normalize=True)
# Out:
# age_group  Response
# 0          0           0.963950
#            1           0.036050
# 1          0           0.827915
#            1           0.172085
# Name: proportion, dtype: float64

# %% [markdown]
# ### policy_channel_group

# %%
data['policy_channel_group'] = (data['Policy_Sales_Channel'] >= 140).astype('int')

# %%
data.policy_channel_group.value_counts(normalize=True)
# Out:
# policy_channel_group
# 0    0.501606
# 1    0.498394
# Name: proportion, dtype: float64

# %%
data.groupby('policy_channel_group')[TARGET].value_counts(normalize=True)
# Out:
# policy_channel_group  Response
# 0                     0           0.816476
#                       1           0.183524
# 1                     0           0.938846
#                       1           0.061154
# Name: proportion, dtype: float64

# %% [markdown]
# # Bivariate analysis

# %%
features = [f for f in data.columns if f not in ('id', TARGET)]
numerical_features = ['Age', 'Region_Code', 'Annual_Premium', 'Policy_Sales_Channel', 'Vintage']
categorical_features = [f for f in features if f not in numerical_features]

# %% [markdown]
# ### Pairplots (numerical features)

# %%
plt.figure(figsize=(14, 9))
sns.pairplot(data=data, kind='scatter', diag_kind='hist', vars=numerical_features, hue=TARGET)
plt.show()

# %% [markdown]
# ### Spearman correlation (numerical features)

# %%
def plot_heatmap(df, masking=False, size=4):
    mask = np.triu(np.ones_like(df)) if masking else None
    plt.figure(figsize=(size, size * 0.75))
    sns.heatmap(
        data=df, mask=mask,
        vmin=-1, vmax=1, center=0,
        annot=True, linewidths=0.1,
        fmt='.2f', annot_kws={'fontsize': 8})
    plt.show()

# %%
corr_df = data[numerical_features].corr(method='spearman')
plot_heatmap(corr_df, masking=True)

# %% [markdown]
# ### Point-biserial correlation (binary vs numerical)

# %%
# all the categorical features are binary
pbsr_dict = {}
for bf in categorical_features:
    pbsr = [binary_continuous(data[bf], data[nf], measure='point_biserial')
            for nf in numerical_features]
    pbsr_dict[bf] = pbsr

# %%
pbsr_df = pd.DataFrame.from_dict(pbsr_dict, orient='index', columns=numerical_features)
plot_heatmap(pbsr_df)

# %% [markdown]
# Moderate and strong correlations between several pairs.

# %% [markdown]
# ### Tetrachoric correlation (binary features)

# %%
tetra_dict = {}
for cf1 in categorical_features:
    corr = [binary_binary(data[cf1], data[cf2], measure='tetrachoric')
            for cf2 in categorical_features]
    tetra_dict[cf1] = corr

# %%
tetra_df = pd.DataFrame.from_dict(tetra_dict, orient='index', columns=categorical_features)
plot_heatmap(tetra_df, masking=True)

# %% [markdown]
# Moderate to strong correlations between several pairs.
# 3-4 instances of perfect correlation, so we will need to remove the redundant features.

# %% [markdown]
# # Feature selection

# %%
def plot_bars(scores, title):
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, len(scores)*0.5))
    ax.set_title(title)
    sns.barplot(x=scores.values, y=scores.index, ax=ax)
    for patch in ax.patches:
        y, height, width = patch.get_y(), patch.get_height(), patch.get_width()
        ax.text(
            width+0.0001, y + height/2, 
            f'{width:.4f}', va='center', ha='left', size=8, 
            bbox={'facecolor': 'white', 'boxstyle': 'round'}
        )

# %% [markdown]
# ### Point-biserial correlation (Binary target vs Numerical features)

# %%
pbsr = [binary_continuous(data[TARGET], data[nf], measure='point_biserial')
        for nf in numerical_features]

pbsr = pd.Series(pbsr, index=numerical_features).sort_values(ascending=False)

# %%
title = 'Target vs numerical features: Point-biserial correlation'
plot_bars(pbsr, title)

# %% [markdown]
# ### ANOVA F-test (Categorical target vs Numerical features)

# %%
anova_test = f_classif(data[numerical_features], data[TARGET])

# %%
pd.DataFrame(
    data={
        'f-statistic': anova_test[0], 
        'p-value': anova_test[1],
        'accepted?': anova_test[1] < 0.05
    },
    index=numerical_features
).sort_values(by='f-statistic')
# Out:
#                       f-statistic       p-value  accepted?
# Vintage                  0.399327  5.274375e-01      False
# Region_Code             42.392837  7.475523e-11       True
# Annual_Premium         196.877522  1.028994e-44       True
# Age                   4758.922048  0.000000e+00       True
# Policy_Sales_Channel  7506.802491  0.000000e+00       True

# %% [markdown]
# ### Tetrachoric correlation

# %%
tetra = [binary_binary(data[TARGET], data[bf], measure='tetrachoric')
        for bf in categorical_features]

tetra = pd.Series(tetra, index=categorical_features).sort_values(ascending=False)

# %%
title = 'Target vs Categorical features: Tetrachoric correlation'
plot_bars(tetra, title)

# %% [markdown]
# ### Chi-squared test of independence (Categorical target vs Categorical features)

# %%
chi2_test = chi2(data[categorical_features], data[TARGET])

# %%
pd.DataFrame(
    data={
        'chi2-statistic': chi2_test[0], 
        'p-value': chi2_test[1],
        'accepted?': chi2_test[1] < 0.05
    },
    index=categorical_features
).sort_values(by='chi2-statistic')
# Out:
#                       chi2-statistic        p-value  accepted?
# Driving_License             0.083762   7.722619e-01      False
# Gender                    481.776676  8.772924e-107       True
# age_group                5527.843218   0.000000e+00       True
# policy_channel_group     6650.210134   0.000000e+00       True
# Vehicle_Age              9899.654778   0.000000e+00       True
# Vehicle_Damage          23681.857822   0.000000e+00       True
# Previously_Insured      24010.249114   0.000000e+00       True

# %% [markdown]
# ### Mutual information score

# %%
#boolean mask for discrete features
cat_mask = [(f in categorical_features) for f in features]

mi_scores = mutual_info_classif(
    data[features], data[TARGET], 
    discrete_features=cat_mask, 
    random_state=SEED
)

mi_scores = pd.Series(mi_scores, index=features).sort_values(ascending=False)

# %%
plot_bars(mi_scores, 'Mutual information scores')

# %% [markdown]
# ### Model-based feature importances

# %% [markdown]
# XGBoost

# %%
model = XGBClassifier(
    n_estimators=100, 
    learning_rate=0.1, 
    max_depth=6, 
    scale_pos_weight=88/12,  # class ratio
    random_state=SEED,
    n_jobs=-1
)
model.fit(data[features], data[TARGET])

fimp = pd.Series(model.feature_importances_, index=model.feature_names_in_).sort_values(ascending=False)

# %%
plot_bars(fimp, 'XGBoost feature importances')

# %% [markdown]
# ExtraTrees:

# %%
model = ExtraTreesClassifier(
    n_estimators=150, 
    max_depth=6, 
    max_features=None, 
    class_weight='balanced', 
    random_state=SEED,
    n_jobs=-1
)
model.fit(data[features], data[TARGET])

fimp = pd.Series(model.feature_importances_, index=model.feature_names_in_).sort_values(ascending=False)

# %%
plot_bars(fimp, 'ExtraTrees feature importances')

# %% [markdown]
# ### Feature sets

# %% [markdown]
# Based on statistical tests we discard some features:

# %%
reduced_features = [f for f in features 
                    if f not in ('Vintage', 'Driving_License')]

# %% [markdown]
# Based on correlation and feature importances, we further remove redundant features:

# %%
minimal_features = [f for f in reduced_features
                    if f not in ('age_group', 'Vehicle_Damage')]

# %%
original_features = [f for f in features 
                     if f not in ('age_group', 'policy_channel_group')]

# %%
feature_sets = {
    'Original': original_features,
    'Extended': features,
    'Reduced': reduced_features,
    'Minimal': minimal_features
}

# %%
for fname, fset in feature_sets.items():
    print(f'{fname} features: {fset}\n')
# Out:
# Original features: ['Gender', 'Age', 'Driving_License', 'Region_Code', 'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium', 'Policy_Sales_Channel', 'Vintage']
#
# Extended features: ['Gender', 'Age', 'Driving_License', 'Region_Code', 'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium', 'Policy_Sales_Channel', 'Vintage', 'age_group', 'policy_channel_group']
#
# Reduced features: ['Gender', 'Age', 'Region_Code', 'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium', 'Policy_Sales_Channel', 'age_group', 'policy_channel_group']
#
# Minimal features: ['Gender', 'Age', 'Region_Code', 'Previously_Insured', 'Vehicle_Age', 'Annual_Premium', 'Policy_Sales_Channel', 'policy_channel_group']

# %% [markdown]
# # Modeling framework

# %% [markdown]
# ### Hold-out set for testing

# %%
train, test, _, _ = train_test_split(
    data, data[TARGET],
    stratify=data[TARGET],
    test_size=0.2,
    shuffle=True,
    random_state=SEED
)

# %% [markdown]
# ### Cross-validation + Threshold tuning + Refit

# %%
def cv_tune_refit(estimator, feature_set, num_folds=7):
    global train, TARGET
    
    skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=SEED)
    model = TunedThresholdClassifierCV(
        estimator=estimator,
        scoring='f1',  # binary f1-score
        thresholds=100,
        cv=skf,
        refit=True,
        n_jobs=-1,
        random_state=SEED
    )
    model.fit(train[feature_set], train[TARGET])
    
    return model

# %% [markdown]
# ### Model evaluation on test set

# %%
def evaluate(model, feature_set):
    global test, TARGET
    
    probs = model.predict_proba(test[feature_set])[:, 1]
    auc = roc_auc_score(test[TARGET], probs)
    preds = model.predict(test[feature_set])
    mcc = matthews_corrcoef(test[TARGET], preds)
    print(f'(Best threshold = {model.best_threshold_:.2f})')
    print(f' Area under ROC curve: {auc:.4f}')
    print(f' Matthew\'s Corr-coeff: {mcc:.4f}')
    print('\nClassification report:')
    print(classification_report(test[TARGET], preds, digits=4))

# %%
def run_experiment(estimator, model_name, save=True):
    global feature_sets
    
    for fname, fset in feature_sets.items():
        print('\n', '-'*15, 'Feature set: ', fname, '-'*15, '\n')
        start_time = time.time()
        model = cv_tune_refit(estimator, fset)
        evaluate(model, fset)
        end_time = time.time()
        print(f'\n(Time taken: {end_time - start_time:.2f} secs)')
        
        if save:
            save_path = f'mdl{model_name}_fs{fname}.joblib'
            joblib.dump(model, save_path)

# %% [markdown]
# # Logistic Regression

# %%
logreg = make_pipeline(
    StandardScaler(),
    LogisticRegression(
        penalty=None,
        tol=2e-4,
        max_iter=1000,
        solver='saga',
        class_weight='balanced',
        random_state=SEED
    )
)

run_experiment(logreg, 'LogReg')
# Out:
#  --------------- Feature set:  Original ---------------
#
# (Best threshold = 0.65)
#  Area under ROC curve: 0.8336
#  Matthew's Corr-coeff: 0.3671
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9598    0.7454    0.8391     66826
#            1     0.2986    0.7761    0.4313      9332
#
#     accuracy                         0.7492     76158
#    macro avg     0.6292    0.7608    0.6352     76158
# weighted avg     0.8787    0.7492    0.7891     76158
#
#
# (Time taken: 15.93 secs)
#
#  --------------- Feature set:  Extended ---------------
#
# (Best threshold = 0.66)
#  Area under ROC curve: 0.8456
#  Matthew's Corr-coeff: 0.3821
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9619    0.7540    0.8454     66826
#            1     0.3085    0.7859    0.4431      9332
#
#     accuracy                         0.7579     76158
#    macro avg     0.6352    0.7700    0.6442     76158
# weighted avg     0.8818    0.7579    0.7961     76158
#
#
# (Time taken: 15.06 secs)
#
#  --------------- Feature set:  Reduced ---------------
#
# (Best threshold = 0.67)
#  Area under ROC curve: 0.8455
#  Matthew's Corr-coeff: 0.3792
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9597    0.7607    0.8487     66826
#            1     0.3104    0.7714    0.4427      9332
#
#     accuracy                         0.7620     76158
#    macro avg     0.6351    0.7661    0.6457     76158
# weighted avg     0.8802    0.7620    0.7990     76158
#
#
# (Time taken: 13.47 secs)
#
#  --------------- Feature set:  Minimal ---------------
#
# (Best threshold = 0.60)
#  Area under ROC curve: 0.8177
#  Matthew's Corr-coeff: 0.3507
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9670    0.6861    0.8027     66826
#            1     0.2702    0.8324    0.4080      9332
#
#     accuracy                         0.7040     76158
#    macro avg     0.6186    0.7592    0.6053     76158
# weighted avg     0.8816    0.7040    0.7543     76158
#
#
# (Time taken: 12.70 secs)

# %% [markdown]
# # Linear Discriminant Analysis

# %%
lda = make_pipeline(
    StandardScaler(),
    LinearDiscriminantAnalysis(solver='svd', tol=2e-4)
)

run_experiment(lda, 'LDA')
# Out:
#  --------------- Feature set:  Original ---------------
#
# (Best threshold = 0.19)
#  Area under ROC curve: 0.8326
#  Matthew's Corr-coeff: 0.3584
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9539    0.7640    0.8484     66826
#            1     0.3032    0.7355    0.4294      9332
#
#     accuracy                         0.7605     76158
#    macro avg     0.6286    0.7498    0.6389     76158
# weighted avg     0.8742    0.7605    0.7971     76158
#
#
# (Time taken: 7.60 secs)
#
#  --------------- Feature set:  Extended ---------------
#
# (Best threshold = 0.18)
#  Area under ROC curve: 0.8423
#  Matthew's Corr-coeff: 0.3785
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9630    0.7442    0.8396     66826
#            1     0.3027    0.7951    0.4385      9332
#
#     accuracy                         0.7504     76158
#    macro avg     0.6328    0.7697    0.6390     76158
# weighted avg     0.8821    0.7504    0.7904     76158
#
#
# (Time taken: 7.43 secs)
#
#  --------------- Feature set:  Reduced ---------------
#
# (Best threshold = 0.18)
#  Area under ROC curve: 0.8421
#  Matthew's Corr-coeff: 0.3768
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9621    0.7465    0.8407     66826
#            1     0.3030    0.7892    0.4379      9332
#
#     accuracy                         0.7517     76158
#    macro avg     0.6325    0.7679    0.6393     76158
# weighted avg     0.8813    0.7517    0.7913     76158
#
#
# (Time taken: 7.12 secs)
#
#  --------------- Feature set:  Minimal ---------------
#
# (Best threshold = 0.15)
#  Area under ROC curve: 0.8185
#  Matthew's Corr-coeff: 0.3473
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9613    0.7104    0.8170     66826
#            1     0.2772    0.7953    0.4111      9332
#
#     accuracy                         0.7208     76158
#    macro avg     0.6192    0.7528    0.6140     76158
# weighted avg     0.8775    0.7208    0.7673     76158
#
#
# (Time taken: 6.83 secs)

# %% [markdown]
# #

# %% [markdown]
# # Quadratic Discriminant Analysis

# %%
qda = make_pipeline(
    StandardScaler(),
    QuadraticDiscriminantAnalysis(reg_param=0.25, tol=1e-3)
)

run_experiment(qda, 'QDA')
# Out:
#  --------------- Feature set:  Original ---------------
#
# (Best threshold = 0.45)
#  Area under ROC curve: 0.8353
#  Matthew's Corr-coeff: 0.3779
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9667    0.7252    0.8288     66826
#            1     0.2945    0.8214    0.4336      9332
#
#     accuracy                         0.7370     76158
#    macro avg     0.6306    0.7733    0.6312     76158
# weighted avg     0.8844    0.7370    0.7803     76158
#
#
# (Time taken: 7.35 secs)
#
#  --------------- Feature set:  Extended ---------------
#
# (Best threshold = 0.54)
#  Area under ROC curve: 0.8418
#  Matthew's Corr-coeff: 0.3793
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9600    0.7595    0.8481     66826
#            1     0.3099    0.7736    0.4425      9332
#
#     accuracy                         0.7612     76158
#    macro avg     0.6350    0.7665    0.6453     76158
# weighted avg     0.8804    0.7612    0.7984     76158
#
#
# (Time taken: 7.42 secs)
#
#  --------------- Feature set:  Reduced ---------------
#
# (Best threshold = 0.44)
#  Area under ROC curve: 0.8422
#  Matthew's Corr-coeff: 0.3807
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9617    0.7529    0.8446     66826
#            1     0.3074    0.7856    0.4419      9332
#
#     accuracy                         0.7569     76158
#    macro avg     0.6346    0.7692    0.6433     76158
# weighted avg     0.8816    0.7569    0.7952     76158
#
#
# (Time taken: 7.09 secs)
#
#  --------------- Feature set:  Minimal ---------------
#
# (Best threshold = 0.28)
#  Area under ROC curve: 0.8212
#  Matthew's Corr-coeff: 0.3587
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9669    0.6983    0.8109     66826
#            1     0.2772    0.8288    0.4155      9332
#
#     accuracy                         0.7143     76158
#    macro avg     0.6221    0.7635    0.6132     76158
# weighted avg     0.8824    0.7143    0.7625     76158
#
#
# (Time taken: 6.65 secs)

# %% [markdown]
# # Gaussian Naive Bayes

# %%
gaussnb = make_pipeline(StandardScaler(), GaussianNB())

run_experiment(gaussnb, 'GaussNB')
# Out:
#  --------------- Feature set:  Original ---------------
#
# (Best threshold = 0.78)
#  Area under ROC curve: 0.8230
#  Matthew's Corr-coeff: 0.3879
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9787    0.6827    0.8043     66826
#            1     0.2823    0.8937    0.4290      9332
#
#     accuracy                         0.7085     76158
#    macro avg     0.6305    0.7882    0.6167     76158
# weighted avg     0.8934    0.7085    0.7583     76158
#
#
# (Time taken: 6.75 secs)
#
#  --------------- Feature set:  Extended ---------------
#
# (Best threshold = 0.13)
#  Area under ROC curve: 0.8242
#  Matthew's Corr-coeff: 0.3914
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9808    0.6780    0.8017     66826
#            1     0.2819    0.9052    0.4299      9332
#
#     accuracy                         0.7058     76158
#    macro avg     0.6314    0.7916    0.6158     76158
# weighted avg     0.8952    0.7058    0.7562     76158
#
#
# (Time taken: 7.34 secs)
#
#  --------------- Feature set:  Reduced ---------------
#
# (Best threshold = 0.08)
#  Area under ROC curve: 0.8240
#  Matthew's Corr-coeff: 0.3908
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9810    0.6765    0.8008     66826
#            1     0.2812    0.9061    0.4292      9332
#
#     accuracy                         0.7046     76158
#    macro avg     0.6311    0.7913    0.6150     76158
# weighted avg     0.8952    0.7046    0.7552     76158
#
#
# (Time taken: 6.70 secs)
#
#  --------------- Feature set:  Minimal ---------------
#
# (Best threshold = 0.15)
#  Area under ROC curve: 0.8055
#  Matthew's Corr-coeff: 0.3605
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9783    0.6453    0.7776     66826
#            1     0.2611    0.8976    0.4045      9332
#
#     accuracy                         0.6762     76158
#    macro avg     0.6197    0.7714    0.5911     76158
# weighted avg     0.8904    0.6762    0.7319     76158
#
#
# (Time taken: 6.51 secs)

# %% [markdown]
# # K-Nearest Neighbors

# %%
knn = make_pipeline(
    StandardScaler(),
    KNeighborsClassifier(
        n_neighbors=7, 
        weights='distance', 
        n_jobs=-1
    )
)

run_experiment(knn, 'KNN')
# Out:
#  --------------- Feature set:  Original ---------------
#
# (Best threshold = 0.09)
#  Area under ROC curve: 0.7819
#  Matthew's Corr-coeff: 0.3461
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9702    0.6631    0.7878     66826
#            1     0.2614    0.8541    0.4003      9332
#
#     accuracy                         0.6865     76158
#    macro avg     0.6158    0.7586    0.5940     76158
# weighted avg     0.8833    0.6865    0.7403     76158
#
#
# (Time taken: 133.67 secs)
#
#  --------------- Feature set:  Extended ---------------
#
# (Best threshold = 0.09)
#  Area under ROC curve: 0.7825
#  Matthew's Corr-coeff: 0.3469
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9704    0.6633    0.7880     66826
#            1     0.2618    0.8550    0.4008      9332
#
#     accuracy                         0.6868     76158
#    macro avg     0.6161    0.7592    0.5944     76158
# weighted avg     0.8836    0.6868    0.7405     76158
#
#
# (Time taken: 160.33 secs)
#
#  --------------- Feature set:  Reduced ---------------
#
# (Best threshold = 0.01)
#  Area under ROC curve: 0.7710
#  Matthew's Corr-coeff: 0.3405
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9649    0.6818    0.7990     66826
#            1     0.2652    0.8223    0.4010      9332
#
#     accuracy                         0.6990     76158
#    macro avg     0.6150    0.7520    0.6000     76158
# weighted avg     0.8791    0.6990    0.7502     76158
#
#
# (Time taken: 60.74 secs)
#
#  --------------- Feature set:  Minimal ---------------
#
# (Best threshold = 0.01)
#  Area under ROC curve: 0.7561
#  Matthew's Corr-coeff: 0.3201
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9621    0.6646    0.7862     66826
#            1     0.2528    0.8124    0.3856      9332
#
#     accuracy                         0.6827     76158
#    macro avg     0.6074    0.7385    0.5859     76158
# weighted avg     0.8752    0.6827    0.7371     76158
#
#
# (Time taken: 41.26 secs)

# %% [markdown]
# # Decision Tree

# %%
dtree = DecisionTreeClassifier(
    max_depth=6, 
    class_weight='balanced',
    random_state=SEED
)

run_experiment(dtree, 'DTree')
# Out:
#  --------------- Feature set:  Original ---------------
#
# (Best threshold = 0.67)
#  Area under ROC curve: 0.8420
#  Matthew's Corr-coeff: 0.3925
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9675    0.7401    0.8387     66826
#            1     0.3064    0.8222    0.4464      9332
#
#     accuracy                         0.7502     76158
#    macro avg     0.6370    0.7812    0.6426     76158
# weighted avg     0.8865    0.7502    0.7906     76158
#
#
# (Time taken: 10.44 secs)
#
#  --------------- Feature set:  Extended ---------------
#
# (Best threshold = 0.67)
#  Area under ROC curve: 0.8420
#  Matthew's Corr-coeff: 0.3925
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9675    0.7401    0.8387     66826
#            1     0.3064    0.8222    0.4464      9332
#
#     accuracy                         0.7502     76158
#    macro avg     0.6370    0.7812    0.6426     76158
# weighted avg     0.8865    0.7502    0.7906     76158
#
#
# (Time taken: 10.15 secs)
#
#  --------------- Feature set:  Reduced ---------------
#
# (Best threshold = 0.67)
#  Area under ROC curve: 0.8419
#  Matthew's Corr-coeff: 0.3925
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9675    0.7401    0.8387     66826
#            1     0.3064    0.8222    0.4464      9332
#
#     accuracy                         0.7502     76158
#    macro avg     0.6370    0.7812    0.6426     76158
# weighted avg     0.8865    0.7502    0.7906     76158
#
#
# (Time taken: 9.47 secs)
#
#  --------------- Feature set:  Minimal ---------------
#
# (Best threshold = 0.63)
#  Area under ROC curve: 0.8262
#  Matthew's Corr-coeff: 0.3683
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9675    0.7085    0.8180     66826
#            1     0.2844    0.8297    0.4237      9332
#
#     accuracy                         0.7234     76158
#    macro avg     0.6260    0.7691    0.6208     76158
# weighted avg     0.8838    0.7234    0.7697     76158
#
#
# (Time taken: 9.63 secs)

# %% [markdown]
# # Random Forest

# %%
rforest = RandomForestClassifier(
    n_estimators=150, 
    max_depth=6, 
    class_weight='balanced',
    random_state=SEED,
    n_jobs=1
)

run_experiment(rforest, 'RForest')
# Out:
#  --------------- Feature set:  Original ---------------
#
# (Best threshold = 0.70)
#  Area under ROC curve: 0.8505
#  Matthew's Corr-coeff: 0.3824
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9559    0.7831    0.8609     66826
#            1     0.3231    0.7411    0.4500      9332
#
#     accuracy                         0.7780     76158
#    macro avg     0.6395    0.7621    0.6554     76158
# weighted avg     0.8783    0.7780    0.8106     76158
#
#
# (Time taken: 146.59 secs)
#
#  --------------- Feature set:  Extended ---------------
#
# (Best threshold = 0.70)
#  Area under ROC curve: 0.8508
#  Matthew's Corr-coeff: 0.3832
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9564    0.7816    0.8602     66826
#            1     0.3226    0.7449    0.4502      9332
#
#     accuracy                         0.7771     76158
#    macro avg     0.6395    0.7632    0.6552     76158
# weighted avg     0.8787    0.7771    0.8099     76158
#
#
# (Time taken: 132.55 secs)
#
#  --------------- Feature set:  Reduced ---------------
#
# (Best threshold = 0.71)
#  Area under ROC curve: 0.8508
#  Matthew's Corr-coeff: 0.3820
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9553    0.7854    0.8621     66826
#            1     0.3241    0.7368    0.4502      9332
#
#     accuracy                         0.7795     76158
#    macro avg     0.6397    0.7611    0.6561     76158
# weighted avg     0.8780    0.7795    0.8116     76158
#
#
# (Time taken: 131.13 secs)
#
#  --------------- Feature set:  Minimal ---------------
#
# (Best threshold = 0.66)
#  Area under ROC curve: 0.8375
#  Matthew's Corr-coeff: 0.3721
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9612    0.7447    0.8392     66826
#            1     0.3003    0.7847    0.4344      9332
#
#     accuracy                         0.7496     76158
#    macro avg     0.6308    0.7647    0.6368     76158
# weighted avg     0.8802    0.7496    0.7896     76158
#
#
# (Time taken: 113.42 secs)

# %% [markdown]
# # Extra Trees

# %%
xtrees = ExtraTreesClassifier(
    n_estimators=150,
    max_depth=6,
    class_weight='balanced',
    random_state=SEED,
    n_jobs=-1
)

run_experiment(xtrees, 'XTrees')
# Out:
#  --------------- Feature set:  Original ---------------
#
# (Best threshold = 0.70)
#  Area under ROC curve: 0.8459
#  Matthew's Corr-coeff: 0.3770
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9583    0.7653    0.8510     66826
#            1     0.3117    0.7613    0.4423      9332
#
#     accuracy                         0.7648     76158
#    macro avg     0.6350    0.7633    0.6466     76158
# weighted avg     0.8790    0.7648    0.8009     76158
#
#
# (Time taken: 89.45 secs)
#
#  --------------- Feature set:  Extended ---------------
#
# (Best threshold = 0.71)
#  Area under ROC curve: 0.8504
#  Matthew's Corr-coeff: 0.3847
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9591    0.7703    0.8544     66826
#            1     0.3174    0.7648    0.4486      9332
#
#     accuracy                         0.7696     76158
#    macro avg     0.6383    0.7676    0.6515     76158
# weighted avg     0.8805    0.7696    0.8047     76158
#
#
# (Time taken: 89.20 secs)
#
#  --------------- Feature set:  Reduced ---------------
#
# (Best threshold = 0.72)
#  Area under ROC curve: 0.8515
#  Matthew's Corr-coeff: 0.3836
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9575    0.7768    0.8577     66826
#            1     0.3202    0.7530    0.4493      9332
#
#     accuracy                         0.7739     76158
#    macro avg     0.6388    0.7649    0.6535     76158
# weighted avg     0.8794    0.7739    0.8077     76158
#
#
# (Time taken: 88.86 secs)
#
#  --------------- Feature set:  Minimal ---------------
#
# (Best threshold = 0.67)
#  Area under ROC curve: 0.8337
#  Matthew's Corr-coeff: 0.3682
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9646    0.7229    0.8264     66826
#            1     0.2899    0.8100    0.4270      9332
#
#     accuracy                         0.7336     76158
#    macro avg     0.6272    0.7665    0.6267     76158
# weighted avg     0.8819    0.7336    0.7775     76158
#
#
# (Time taken: 67.93 secs)

# %% [markdown]
# # AdaBoost

# %%
base_estimator = DecisionTreeClassifier(
    max_depth=6, 
    class_weight='balanced',
    random_state=SEED
)

adaboost = AdaBoostClassifier(
    estimator=base_estimator, 
    n_estimators=50, 
    learning_rate=0.05,
    algorithm='SAMME',
    random_state=SEED
)

run_experiment(adaboost, 'AdaBoost')
# Out:
#  --------------- Feature set:  Original ---------------
#
# (Best threshold = 0.83)
#  Area under ROC curve: 0.8394
#  Matthew's Corr-coeff: 0.3894
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9646    0.7502    0.8440     66826
#            1     0.3097    0.8026    0.4470      9332
#
#     accuracy                         0.7566     76158
#    macro avg     0.6371    0.7764    0.6455     76158
# weighted avg     0.8843    0.7566    0.7953     76158
#
#
# (Time taken: 197.77 secs)
#
#  --------------- Feature set:  Extended ---------------
#
# (Best threshold = 0.83)
#  Area under ROC curve: 0.8394
#  Matthew's Corr-coeff: 0.3894
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9646    0.7502    0.8440     66826
#            1     0.3097    0.8026    0.4470      9332
#
#     accuracy                         0.7566     76158
#    macro avg     0.6371    0.7764    0.6455     76158
# weighted avg     0.8843    0.7566    0.7953     76158
#
#
# (Time taken: 211.12 secs)
#
#  --------------- Feature set:  Reduced ---------------
#
# (Best threshold = 0.84)
#  Area under ROC curve: 0.8404
#  Matthew's Corr-coeff: 0.3839
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9579    0.7751    0.8569     66826
#            1     0.3195    0.7562    0.4492      9332
#
#     accuracy                         0.7728     76158
#    macro avg     0.6387    0.7657    0.6530     76158
# weighted avg     0.8797    0.7728    0.8069     76158
#
#
# (Time taken: 174.32 secs)
#
#  --------------- Feature set:  Minimal ---------------
#
# (Best threshold = 0.86)
#  Area under ROC curve: 0.8269
#  Matthew's Corr-coeff: 0.3643
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9561    0.7605    0.8471     66826
#            1     0.3041    0.7497    0.4327      9332
#
#     accuracy                         0.7591     76158
#    macro avg     0.6301    0.7551    0.6399     76158
# weighted avg     0.8762    0.7591    0.7963     76158
#
#
# (Time taken: 132.08 secs)

# %% [markdown]
# # Multi-Layer Perceptron

# %%
mlpnn = make_pipeline(
    StandardScaler(),
    MLPClassifier(
        activation='relu',
        solver='adam',
        alpha=1e-4,
        learning_rate_init=1e-3,
        max_iter=1000,
        tol=1e-4,
        early_stopping=True,
        validation_fraction=0.1,
        n_iter_no_change=25,
        random_state=SEED
    )
)

run_experiment(mlpnn, 'MLP')
# Out:
#  --------------- Feature set:  Original ---------------
#
# (Best threshold = 0.22)
#  Area under ROC curve: 0.8512
#  Matthew's Corr-coeff: 0.3899
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9624    0.7609    0.8499     66826
#            1     0.3150    0.7871    0.4499      9332
#
#     accuracy                         0.7641     76158
#    macro avg     0.6387    0.7740    0.6499     76158
# weighted avg     0.8831    0.7641    0.8009     76158
#
#
# (Time taken: 247.47 secs)
#
#  --------------- Feature set:  Extended ---------------
#
# (Best threshold = 0.23)
#  Area under ROC curve: 0.8528
#  Matthew's Corr-coeff: 0.3865
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9574    0.7807    0.8601     66826
#            1     0.3235    0.7511    0.4523      9332
#
#     accuracy                         0.7771     76158
#    macro avg     0.6405    0.7659    0.6562     76158
# weighted avg     0.8797    0.7771    0.8101     76158
#
#
# (Time taken: 234.82 secs)
#
#  --------------- Feature set:  Reduced ---------------
#
# (Best threshold = 0.23)
#  Area under ROC curve: 0.8517
#  Matthew's Corr-coeff: 0.3892
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9603    0.7700    0.8547     66826
#            1     0.3192    0.7721    0.4517      9332
#
#     accuracy                         0.7703     76158
#    macro avg     0.6397    0.7711    0.6532     76158
# weighted avg     0.8817    0.7703    0.8053     76158
#
#
# (Time taken: 178.89 secs)
#
#  --------------- Feature set:  Minimal ---------------
#
# (Best threshold = 0.21)
#  Area under ROC curve: 0.8385
#  Matthew's Corr-coeff: 0.3663
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9590    0.7479    0.8404     66826
#            1     0.2994    0.7712    0.4313      9332
#
#     accuracy                         0.7508     76158
#    macro avg     0.6292    0.7596    0.6359     76158
# weighted avg     0.8782    0.7508    0.7903     76158
#
#
# (Time taken: 190.00 secs)

# %% [markdown]
# # XGBoost

# %%
class_ratio = train[TARGET].value_counts()[0] / train[TARGET].value_counts()[1]

# %%
xgb = XGBClassifier(
    booster='gbtree',
    tree_method='hist',
    objective='binary:logistic',
    eval_metric='auc',
    scale_pos_weight=class_ratio,
    learning_rate=0.01,
    n_estimators=1000,
    device='cpu',
    verbosity=0,
    seed=SEED
)

run_experiment(xgb, 'XGBoost')
# Out:
#  --------------- Feature set:  Original ---------------
#
# (Best threshold = 0.68)
#  Area under ROC curve: 0.8585
#  Matthew's Corr-coeff: 0.3980
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9596    0.7834    0.8626     66826
#            1     0.3299    0.7637    0.4608      9332
#
#     accuracy                         0.7810     76158
#    macro avg     0.6447    0.7735    0.6617     76158
# weighted avg     0.8824    0.7810    0.8133     76158
#
#
# (Time taken: 119.62 secs)
#
#  --------------- Feature set:  Extended ---------------
#
# (Best threshold = 0.68)
#  Area under ROC curve: 0.8585
#  Matthew's Corr-coeff: 0.3980
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9596    0.7834    0.8626     66826
#            1     0.3299    0.7637    0.4608      9332
#
#     accuracy                         0.7810     76158
#    macro avg     0.6447    0.7735    0.6617     76158
# weighted avg     0.8824    0.7810    0.8133     76158
#
#
# (Time taken: 129.25 secs)
#
#  --------------- Feature set:  Reduced ---------------
#
# (Best threshold = 0.68)
#  Area under ROC curve: 0.8584
#  Matthew's Corr-coeff: 0.3967
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9590    0.7848    0.8632     66826
#            1     0.3301    0.7595    0.4602      9332
#
#     accuracy                         0.7817     76158
#    macro avg     0.6445    0.7722    0.6617     76158
# weighted avg     0.8819    0.7817    0.8138     76158
#
#
# (Time taken: 118.55 secs)
#
#  --------------- Feature set:  Minimal ---------------
#
# (Best threshold = 0.66)
#  Area under ROC curve: 0.8459
#  Matthew's Corr-coeff: 0.3765
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9590    0.7612    0.8487     66826
#            1     0.3096    0.7667    0.4411      9332
#
#     accuracy                         0.7619     76158
#    macro avg     0.6343    0.7640    0.6449     76158
# weighted avg     0.8794    0.7619    0.7988     76158
#
#
# (Time taken: 111.26 secs)

# %% [markdown]
# # CatBoost

# %%
catb = CatBoostClassifier(
    loss_function='Logloss',
    eval_metric='Logloss',
    metric_period=1,
    iterations=1000,
    learning_rate=0.01,
    auto_class_weights='SqrtBalanced',
    task_type='CPU',
    verbose=False,
    random_state=SEED
)

run_experiment(catb, 'CatBoost')
# Out:
#  --------------- Feature set:  Original ---------------
#
# (Best threshold = 0.46)
#  Area under ROC curve: 0.8579
#  Matthew's Corr-coeff: 0.3951
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9576    0.7895    0.8654     66826
#            1     0.3321    0.7496    0.4602      9332
#
#     accuracy                         0.7846     76158
#    macro avg     0.6448    0.7695    0.6628     76158
# weighted avg     0.8809    0.7846    0.8158     76158
#
#
# (Time taken: 389.33 secs)
#
#  --------------- Feature set:  Extended ---------------
#
# (Best threshold = 0.45)
#  Area under ROC curve: 0.8578
#  Matthew's Corr-coeff: 0.3981
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9601    0.7812    0.8614     66826
#            1     0.3288    0.7675    0.4603      9332
#
#     accuracy                         0.7795     76158
#    macro avg     0.6444    0.7743    0.6609     76158
# weighted avg     0.8827    0.7795    0.8123     76158
#
#
# (Time taken: 387.89 secs)
#
#  --------------- Feature set:  Reduced ---------------
#
# (Best threshold = 0.45)
#  Area under ROC curve: 0.8577
#  Matthew's Corr-coeff: 0.3975
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9592    0.7846    0.8632     66826
#            1     0.3304    0.7611    0.4608      9332
#
#     accuracy                         0.7817     76158
#    macro avg     0.6448    0.7729    0.6620     76158
# weighted avg     0.8822    0.7817    0.8138     76158
#
#
# (Time taken: 382.10 secs)
#
#  --------------- Feature set:  Minimal ---------------
#
# (Best threshold = 0.42)
#  Area under ROC curve: 0.8449
#  Matthew's Corr-coeff: 0.3781
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9609    0.7538    0.8448     66826
#            1     0.3068    0.7803    0.4405      9332
#
#     accuracy                         0.7571     76158
#    macro avg     0.6339    0.7671    0.6426     76158
# weighted avg     0.8807    0.7571    0.7953     76158
#
#
# (Time taken: 379.12 secs)

# %% [markdown]
# # LightGBM

# %%
lgbm = LGBMClassifier(
    boosting_type='gbdt',
    metric='auc',
    learning_rate=0.01,
    n_estimators=1000,
    is_unbalance=True,
    verbosity=-1,
    random_state=SEED
)

run_experiment(lgbm, 'LightGBM')
# Out:
#  --------------- Feature set:  Original ---------------
#
# (Best threshold = 0.67)
#  Area under ROC curve: 0.8587
#  Matthew's Corr-coeff: 0.3978
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9596    0.7832    0.8625     66826
#            1     0.3298    0.7637    0.4606      9332
#
#     accuracy                         0.7809     76158
#    macro avg     0.6447    0.7735    0.6616     76158
# weighted avg     0.8824    0.7809    0.8132     76158
#
#
# (Time taken: 301.51 secs)
#
#  --------------- Feature set:  Extended ---------------
#
# (Best threshold = 0.67)
#  Area under ROC curve: 0.8587
#  Matthew's Corr-coeff: 0.3976
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9597    0.7823    0.8620     66826
#            1     0.3292    0.7649    0.4602      9332
#
#     accuracy                         0.7802     76158
#    macro avg     0.6444    0.7736    0.6611     76158
# weighted avg     0.8825    0.7802    0.8128     76158
#
#
# (Time taken: 340.75 secs)
#
#  --------------- Feature set:  Reduced ---------------
#
# (Best threshold = 0.67)
#  Area under ROC curve: 0.8587
#  Matthew's Corr-coeff: 0.3983
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9600    0.7818    0.8618     66826
#            1     0.3292    0.7668    0.4606      9332
#
#     accuracy                         0.7799     76158
#    macro avg     0.6446    0.7743    0.6612     76158
# weighted avg     0.8827    0.7799    0.8126     76158
#
#
# (Time taken: 323.82 secs)
#
#  --------------- Feature set:  Minimal ---------------
#
# (Best threshold = 0.66)
#  Area under ROC curve: 0.8462
#  Matthew's Corr-coeff: 0.3753
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.9582    0.7635    0.8498     66826
#            1     0.3101    0.7614    0.4407      9332
#
#     accuracy                         0.7632     76158
#    macro avg     0.6342    0.7624    0.6453     76158
# weighted avg     0.8788    0.7632    0.7997     76158
#
#
# (Time taken: 331.18 secs)
