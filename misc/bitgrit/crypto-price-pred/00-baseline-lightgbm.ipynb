# %% [markdown]
# # Setup

# %%
import gc
import warnings

gc.enable()
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
pd.set_option('display.precision', 4)
pd.set_option('display.max_columns', None)

import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score

SEED = 2024

# %%
lgb.__version__
# Out:
# '4.2.0'

# %%
DATA_DIR = '/kaggle/input/bitgrit-crypto-price-prediction'

train = pd.read_csv(f'{DATA_DIR}/train.csv')
test = pd.read_csv(f'{DATA_DIR}/test.csv')
sample_sub = pd.read_csv(f'{DATA_DIR}/solution_format.csv')

# %% [markdown]
# # Data overview

# %%
sample_sub.columns
# Out:
# Index(['ID', 'Target'], dtype='object')

# %%
train.head()
# Out:
#    ID  TR_1_EventInd  TR_2_EventInd  TR_3_EventInd  feature_10_A  \
# 0   1            NaN            NaN            NaN           0.0
# 1   2            NaN            NaN            NaN           0.0
# 2   3            NaN            NaN            NaN           0.0
# 3   4            NaN            NaN            NaN           1.0
# 4   5            NaN            NaN            1.0           1.0
#
#    feature_10_B  feature_10_F  feature_10_G  feature_1_A  feature_1_B  \
# 0           NaN           0.0           0.0          NaN          NaN
# 1           NaN           0.0           0.0          NaN          NaN
# 2         0.023           0.0           0.0          1.0        0.004
# 3         0.019           0.0           2.0          0.0        0.005
# 4         0.023           0.0           2.0          1.0        0.014
#
#    feature_1_C  feature_1_D  feature_1_E  feature_1_F  feature_1_G  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2      -0.2244      -1.3548     122.7936          1.0          1.0
# 3      -1.3725      -1.4973     116.5155          0.0          0.0
# 4       1.6641       2.3542     123.7083          1.0          1.0
#
#    feature_2_A  feature_2_B  feature_2_C  feature_2_D  feature_2_E  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          0.0        0.011      -1.2904       1.2931      41.9933
# 3          1.0        0.005       1.8910       0.1048      45.5508
# 4          1.0        0.014       0.8111       0.7767      56.9611
#
#    feature_2_F  feature_2_G  feature_3_A  feature_3_B  feature_3_C  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          1.0          1.0          0.0        0.010      -1.7287
# 3          1.0          2.0          1.0        0.012       0.0778
# 4          1.0          2.0          1.0        0.013       0.2570
#
#    feature_3_D  feature_3_E  feature_3_F  feature_3_G  feature_4_A  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2       0.3817     114.9724          1.0          1.0          0.0
# 3      -0.9358     134.0235          1.0          1.0          1.0
# 4       0.1122     150.7831          1.0          1.0          0.0
#
#    feature_4_B  feature_4_C  feature_4_E  feature_4_F  feature_4_G  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2        0.010       0.1208     106.7018          0.0          1.0
# 3        0.004       1.5798     112.4135          1.0          3.0
# 4        0.004       0.7826          NaN          0.0          2.0
#
#    feature_5_A  feature_5_B  feature_5_C  feature_5_D  feature_5_E  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          1.0        0.018      -1.0708      -0.6021      11.4924
# 3          1.0        0.068       3.3580       3.2775      24.7031
# 4          0.0        0.019       0.7324      -0.8972      52.2727
#
#    feature_5_F  feature_5_G  feature_6_A  feature_6_B  feature_6_C  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          1.0          1.0          1.0        0.009      -0.7593
# 3          1.0          2.0          0.0        0.004       1.1889
# 4          1.0          0.0          0.0        0.015      -1.1118
#
#    feature_6_D  feature_6_E  feature_6_F  feature_6_G  feature_7_A  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2       0.2421     110.2917          1.0          1.0          0.0
# 3      -0.0793     125.4054          1.0          5.0          1.0
# 4       0.2605     156.6009          1.0          0.0          0.0
#
#    feature_7_B  feature_7_C  feature_7_D  feature_7_E  feature_7_F  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2        0.010      -1.7708       0.5285     209.7878          1.0
# 3        0.003       1.0441      -0.7610     228.4739          1.0
# 4        0.011      -1.0811      -0.6182     263.8278          1.0
#
#    feature_7_G  feature_8_A  feature_8_B  feature_8_C  feature_8_D  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          0.0          1.0        0.016      -0.8865      -0.9410
# 3          1.0          1.0        0.023       1.6473      -0.3779
# 4          0.0          1.0        0.039      -1.1132       0.1490
#
#    feature_8_E  feature_8_F  feature_8_G  feature_9_A  feature_9_B  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2      14.8012          0.0          1.0          0.0        0.032
# 3      16.2052          1.0          2.0          0.0        0.033
# 4      22.2990          0.0          1.0          1.0        0.084
#
#    feature_9_C  feature_9_D  feature_9_E  feature_9_F  feature_9_G  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2      -1.9380       0.7300       2.1619          0.0          1.0
# 3       0.6570      -0.9823       2.4165          0.0          0.0
# 4       2.2816       1.2752       3.4386          1.0          2.0
#
#    feature_X_A  feature_X_B  feature_X_C  feature_X_D  index_1  index_2  \
# 0            1        0.049       1.5425      -0.2747      0.0      0.0
# 1            1        0.015       1.2875      -1.1406      NaN      NaN
# 2            1        0.006       0.2515      -1.2216      NaN      NaN
# 3            1        0.039       1.6738       0.5278      NaN      NaN
# 4            0        0.037       0.2634      -0.3020      NaN      NaN
#
#    index_3  Target
# 0      1.0       0
# 1      NaN       0
# 2      NaN       0
# 3      NaN       1
# 4      NaN       0

# %%
train.shape, test.shape, sample_sub.shape
# Out:
# ((2660, 78), (666, 77), (666, 2))

# %% [markdown]
# **Target distribution**

# %%
TARGET = 'Target'
train[TARGET].value_counts(normalize=True)
# Out:
# Target
# 1    0.5677
# 0    0.4323
# Name: proportion, dtype: float64

# %% [markdown]
# **% of missing values**

# %%
(train.isna().sum() / len(train) * 100).to_frame().T
# Out:
#     ID  TR_1_EventInd  TR_2_EventInd  TR_3_EventInd  feature_10_A  \
# 0  0.0        97.2556        97.7068        96.3534       16.8421
#
#    feature_10_B  feature_10_F  feature_10_G  feature_1_A  feature_1_B  \
# 0       30.7143       16.8421       16.8421      30.6767      30.6767
#
#    feature_1_C  feature_1_D  feature_1_E  feature_1_F  feature_1_G  \
# 0      30.8271      30.8271      34.5113      30.6767      30.6767
#
#    feature_2_A  feature_2_B  feature_2_C  feature_2_D  feature_2_E  \
# 0      30.6767      30.6767      30.8271      30.8271      34.5113
#
#    feature_2_F  feature_2_G  feature_3_A  feature_3_B  feature_3_C  \
# 0      30.6767      30.6767      30.6767      30.6767      30.8271
#
#    feature_3_D  feature_3_E  feature_3_F  feature_3_G  feature_4_A  \
# 0      30.8271      34.5113      30.6767      30.6767      28.0075
#
#    feature_4_B  feature_4_C  feature_4_E  feature_4_F  feature_4_G  \
# 0      28.1203      29.1729      43.1203      28.0075      28.0075
#
#    feature_5_A  feature_5_B  feature_5_C  feature_5_D  feature_5_E  \
# 0      30.7143      30.7143      30.8647      30.8647      34.5489
#
#    feature_5_F  feature_5_G  feature_6_A  feature_6_B  feature_6_C  \
# 0      30.7143      30.7143      30.6767      30.6767      30.8271
#
#    feature_6_D  feature_6_E  feature_6_F  feature_6_G  feature_7_A  \
# 0      30.8271      34.5113      30.6767      30.6767      30.6767
#
#    feature_7_B  feature_7_C  feature_7_D  feature_7_E  feature_7_F  \
# 0      30.6767      30.8271      30.8271      34.5113      30.6767
#
#    feature_7_G  feature_8_A  feature_8_B  feature_8_C  feature_8_D  \
# 0      30.6767      30.6767      30.6767      30.8271      30.8271
#
#    feature_8_E  feature_8_F  feature_8_G  feature_9_A  feature_9_B  \
# 0      34.5113      30.6767      30.6767      30.7143      30.7143
#
#    feature_9_C  feature_9_D  feature_9_E  feature_9_F  feature_9_G  \
# 0      30.8647      30.8647      34.5489      30.7143      30.7143
#
#    feature_X_A  feature_X_B  feature_X_C  feature_X_D  index_1  index_2  \
# 0          0.0          0.0          0.0          0.0  96.4286  96.4286
#
#    index_3  Target
# 0  96.4286     0.0

# %%
(test.isna().sum() / len(test) * 100).to_frame().T
# Out:
#     ID  TR_1_EventInd  TR_2_EventInd  TR_3_EventInd  feature_10_A  \
# 0  0.0         98.048        98.3483        95.3453       16.5165
#
#    feature_10_B  feature_10_F  feature_10_G  feature_1_A  feature_1_B  \
# 0        33.033       16.5165       16.5165      32.8829      32.8829
#
#    feature_1_C  feature_1_D  feature_1_E  feature_1_F  feature_1_G  \
# 0       33.033       33.033      37.2372      32.8829      32.8829
#
#    feature_2_A  feature_2_B  feature_2_C  feature_2_D  feature_2_E  \
# 0      32.8829      32.8829       33.033       33.033      37.2372
#
#    feature_2_F  feature_2_G  feature_3_A  feature_3_B  feature_3_C  \
# 0      32.8829      32.8829      32.8829      32.8829       33.033
#
#    feature_3_D  feature_3_E  feature_3_F  feature_3_G  feature_4_A  \
# 0       33.033      37.2372      32.8829      32.8829      30.7808
#
#    feature_4_B  feature_4_C  feature_4_E  feature_4_F  feature_4_G  \
# 0      30.7808       33.033      45.7958      30.7808      30.7808
#
#    feature_5_A  feature_5_B  feature_5_C  feature_5_D  feature_5_E  \
# 0      32.8829      32.8829       33.033       33.033      37.2372
#
#    feature_5_F  feature_5_G  feature_6_A  feature_6_B  feature_6_C  \
# 0      32.8829      32.8829      32.8829      32.8829       33.033
#
#    feature_6_D  feature_6_E  feature_6_F  feature_6_G  feature_7_A  \
# 0       33.033      37.2372      32.8829      32.8829      32.8829
#
#    feature_7_B  feature_7_C  feature_7_D  feature_7_E  feature_7_F  \
# 0      32.8829       33.033       33.033      37.2372      32.8829
#
#    feature_7_G  feature_8_A  feature_8_B  feature_8_C  feature_8_D  \
# 0      32.8829      32.8829      32.8829       33.033       33.033
#
#    feature_8_E  feature_8_F  feature_8_G  feature_9_A  feature_9_B  \
# 0      37.2372      32.8829      32.8829      32.8829      32.8829
#
#    feature_9_C  feature_9_D  feature_9_E  feature_9_F  feature_9_G  \
# 0       33.033       33.033      37.2372      32.8829      32.8829
#
#    feature_X_A  feature_X_B  feature_X_C  feature_X_D  index_1  index_2  \
# 0          0.0          0.0          0.0          0.0  97.8979  97.8979
#
#    index_3
# 0  97.8979

# %% [markdown]
# **Number of unique values**

# %%
train.nunique().to_frame().T  # not including NaN
# Out:
#      ID  TR_1_EventInd  TR_2_EventInd  TR_3_EventInd  feature_10_A  \
# 0  2660              1              1              1             2
#
#    feature_10_B  feature_10_F  feature_10_G  feature_1_A  feature_1_B  \
# 0           110             1             5            2           34
#
#    feature_1_C  feature_1_D  feature_1_E  feature_1_F  feature_1_G  \
# 0         1840         1840         1742            2           11
#
#    feature_2_A  feature_2_B  feature_2_C  feature_2_D  feature_2_E  \
# 0            2           45         1840         1840         1742
#
#    feature_2_F  feature_2_G  feature_3_A  feature_3_B  feature_3_C  \
# 0            2           12            2           66         1840
#
#    feature_3_D  feature_3_E  feature_3_F  feature_3_G  feature_4_A  \
# 0         1840         1742            2           11            2
#
#    feature_4_B  feature_4_C  feature_4_E  feature_4_F  feature_4_G  \
# 0           35         1884         1513            2           12
#
#    feature_5_A  feature_5_B  feature_5_C  feature_5_D  feature_5_E  \
# 0            2          101         1839         1839         1741
#
#    feature_5_F  feature_5_G  feature_6_A  feature_6_B  feature_6_C  \
# 0            2           11            2           61         1840
#
#    feature_6_D  feature_6_E  feature_6_F  feature_6_G  feature_7_A  \
# 0         1840         1742            2           12            2
#
#    feature_7_B  feature_7_C  feature_7_D  feature_7_E  feature_7_F  \
# 0           56         1840         1840         1742            2
#
#    feature_7_G  feature_8_A  feature_8_B  feature_8_C  feature_8_D  \
# 0            9            2          124         1840         1840
#
#    feature_8_E  feature_8_F  feature_8_G  feature_9_A  feature_9_B  \
# 0         1741            2           14            2          164
#
#    feature_9_C  feature_9_D  feature_9_E  feature_9_F  feature_9_G  \
# 0         1838         1839         1721            2           12
#
#    feature_X_A  feature_X_B  feature_X_C  feature_X_D  index_1  index_2  \
# 0            2          189         2660         2660        7       25
#
#    index_3  Target
# 0       35       2

# %%
test.nunique().to_frame().T
# Out:
#     ID  TR_1_EventInd  TR_2_EventInd  TR_3_EventInd  feature_10_A  \
# 0  666              1              1              1             2
#
#    feature_10_B  feature_10_F  feature_10_G  feature_1_A  feature_1_B  \
# 0            72             1             5            2           28
#
#    feature_1_C  feature_1_D  feature_1_E  feature_1_F  feature_1_G  \
# 0          446          446          418            2            9
#
#    feature_2_A  feature_2_B  feature_2_C  feature_2_D  feature_2_E  \
# 0            2           30          446          446          417
#
#    feature_2_F  feature_2_G  feature_3_A  feature_3_B  feature_3_C  \
# 0            2            9            2           47          446
#
#    feature_3_D  feature_3_E  feature_3_F  feature_3_G  feature_4_A  \
# 0          446          418            2            8            2
#
#    feature_4_B  feature_4_C  feature_4_E  feature_4_F  feature_4_G  \
# 0           26          446          361            2           11
#
#    feature_5_A  feature_5_B  feature_5_C  feature_5_D  feature_5_E  \
# 0            2           79          446          446          418
#
#    feature_5_F  feature_5_G  feature_6_A  feature_6_B  feature_6_C  \
# 0            2            9            2           47          446
#
#    feature_6_D  feature_6_E  feature_6_F  feature_6_G  feature_7_A  \
# 0          446          418            2           10            2
#
#    feature_7_B  feature_7_C  feature_7_D  feature_7_E  feature_7_F  \
# 0           41          446          446          417            2
#
#    feature_7_G  feature_8_A  feature_8_B  feature_8_C  feature_8_D  \
# 0            8            2           89          446          446
#
#    feature_8_E  feature_8_F  feature_8_G  feature_9_A  feature_9_B  \
# 0          418            2           10            2          122
#
#    feature_9_C  feature_9_D  feature_9_E  feature_9_F  feature_9_G  \
# 0          446          446          417            2           10
#
#    feature_X_A  feature_X_B  feature_X_C  feature_X_D  index_1  index_2  \
# 0            2          126          666          666        6        5
#
#    index_3
# 0       12

# %% [markdown]
# # Data preparation

# %% [markdown]
# **Feature sets**

# %%
# ID is unique identifier. Others have only 1 unique value i.e., zero variance.
all_features = [f for f in test.columns if f not in ('ID')]

# less than 90% missing
features_90 = [f for f in all_features if train[f].isna().sum() / len(train) < 0.9]

# less than 25% missing
features_25 = [f for f in all_features if train[f].isna().sum() / len(train) < 0.25]

# no values missing
features_0 = [f for f in all_features if train[f].isna().sum() == 0]

# %%
len(all_features), len(features_90), len(features_25), len(features_0)
# Out:
# (76, 70, 7, 4)

# %% [markdown]
# **Categorical features**

# %%
CAT_FEAT = [f for f in all_features if train[f].nunique() == 2]

# %% [markdown]
# # Modeling framework

# %%
def comp_metric(y_true, y_pred):
    return f1_score(y_true, y_pred)

# %%
def lgbm_eval_metric(y_true, y_pred):
    is_higher_better = True
    y_pred = (y_pred >= 0.5).astype('int')
    return 'f1_score', f1_score(y_true, y_pred), is_higher_better

# %%
def custom_cv(features, model, folds=7, seed=SEED):
    X, y = train[features], train[TARGET]
    X_test = test[features]
    cat_feat = [f for f in features if f in CAT_FEAT]
    
    oof_preds = {}
    test_preds = {}
    scores = []

    cv = StratifiedKFold(n_splits=folds, shuffle=True, random_state=seed)
    for fold, (train_ids, val_ids) in enumerate(cv.split(X, y)):
        X_train, y_train = X.iloc[train_ids], y.iloc[train_ids]
        X_val, y_val = X.iloc[val_ids], y.iloc[val_ids]

        model.fit(
            X_train, y_train,
            eval_set=[(X_val, y_val)],
            eval_metric=lgbm_eval_metric,
            feature_name=features,
            categorical_feature=cat_feat)

        val_preds = model.predict(X_val)
        oof_preds.update(dict(zip(val_ids, val_preds)))
        
        test_preds[f'fold{fold}'] = model.predict(X_test)

        score = comp_metric(y_val, val_preds)
        scores.append(score)
        print(f'Fold #{fold:>2}: {score:.5f} ({model.best_iteration_:>4} rounds)')
        _ = gc.collect()

    test_preds = pd.DataFrame.from_dict(test_preds)
    test_preds['mode'] = test_preds.mode(axis=1)[0].astype('int')
    
    oof_preds = pd.Series(oof_preds).sort_index()
    print(f'\nAvg: {np.mean(scores):.5f} +/- {np.std(scores):.5f}')
    print(f'OOF: {comp_metric(y, oof_preds):.5f}\n')
    
    return oof_preds, test_preds

# %%
def create_submission_files(preds, config, notebook='00'):
    sub = sample_sub.copy()
    sub[TARGET] = preds['mode']
    sub.to_csv(f'nb{notebook}_{config}.csv', index=False)

# %% [markdown]
# # Experiments

# %%
op = {}  # OOF preds
tp = {}  # Test preds

# %%
BASE_PARAMS = {
    'objective': 'binary',
    'n_estimators': 1000,
    'learning_rate': 0.01,
    'early_stopping_rounds': 200,
    'data_sample_strategy': 'goss',
    'max_cat_to_onehot': 2,
    'verbosity': -1,
    'device_type': 'cpu',
    'num_threads': 4,
}

# %%
# %%time

feature_set = 'ALL'
folds = 7
seed = SEED
config = f'feat{feature_set}_fold{folds}_seed{seed}'

model = lgb.LGBMClassifier(**BASE_PARAMS, seed=seed)
op[config], tp[config] = custom_cv(all_features, model, folds=folds, seed=seed)

create_submission_files(tp[config], config)
# Out:
# Fold # 0: 0.79755 (  67 rounds)
# Fold # 1: 0.76923 ( 106 rounds)
# Fold # 2: 0.78873 ( 117 rounds)
# Fold # 3: 0.77642 ( 112 rounds)
# Fold # 4: 0.75781 (  40 rounds)
# Fold # 5: 0.76074 (  98 rounds)
# Fold # 6: 0.76680 ( 101 rounds)
#
# Avg: 0.77390 +/- 0.01357
# OOF: 0.77379
#
# CPU times: user 33.8 s, sys: 11.7 s, total: 45.5 s
# Wall time: 29.4 s

# %%
# %%time

feature_set = 'F90'
folds = 7
seed = SEED
config = f'feat{feature_set}_fold{folds}_seed{seed}'

model = lgb.LGBMClassifier(**BASE_PARAMS, seed=seed)
op[config], tp[config] = custom_cv(features_90, model, folds=folds, seed=seed)

create_submission_files(tp[config], config)
# Out:
# Fold # 0: 0.79755 (  67 rounds)
# Fold # 1: 0.76923 ( 106 rounds)
# Fold # 2: 0.78873 ( 117 rounds)
# Fold # 3: 0.77642 ( 112 rounds)
# Fold # 4: 0.75781 (  40 rounds)
# Fold # 5: 0.76074 (  98 rounds)
# Fold # 6: 0.76680 ( 101 rounds)
#
# Avg: 0.77390 +/- 0.01357
# OOF: 0.77379
#
# CPU times: user 30.7 s, sys: 9.23 s, total: 40 s
# Wall time: 24.7 s

# %%
# %%time

feature_set = 'F25'
folds = 7
seed = SEED
config = f'feat{feature_set}_fold{folds}_seed{seed}'

model = lgb.LGBMClassifier(**BASE_PARAMS, seed=seed)
op[config], tp[config] = custom_cv(features_25, model, folds=folds, seed=seed)

create_submission_files(tp[config], config)
# Out:
# Fold # 0: 0.72269 (   1 rounds)
# Fold # 1: 0.71986 (  28 rounds)
# Fold # 2: 0.72483 (   1 rounds)
# Fold # 3: 0.72483 (   1 rounds)
# Fold # 4: 0.72483 (   1 rounds)
# Fold # 5: 0.72483 (   1 rounds)
# Fold # 6: 0.72483 (   1 rounds)
#
# Avg: 0.72382 +/- 0.00177
# OOF: 0.72382
#
# CPU times: user 11.9 s, sys: 6.81 s, total: 18.7 s
# Wall time: 15 s

# %%
# %%time

feature_set = 'F0'
folds = 7
seed = SEED
config = f'feat{feature_set}_fold{folds}_seed{seed}'

model = lgb.LGBMClassifier(**BASE_PARAMS, seed=seed)
op[config], tp[config] = custom_cv(features_0, model, folds=folds, seed=seed)

create_submission_files(tp[config], config)
# Out:
# Fold # 0: 0.72269 (   1 rounds)
# Fold # 1: 0.72572 (  38 rounds)
# Fold # 2: 0.72483 (   1 rounds)
# Fold # 3: 0.72483 (   1 rounds)
# Fold # 4: 0.72483 (   1 rounds)
# Fold # 5: 0.72483 (   1 rounds)
# Fold # 6: 0.72483 (   1 rounds)
#
# Avg: 0.72465 +/- 0.00086
# OOF: 0.72465
#
# CPU times: user 11.6 s, sys: 6.61 s, total: 18.2 s
# Wall time: 14.8 s

# %%
# %%time

feature_set = 'ALL'
folds = 10
seed = SEED
config = f'feat{feature_set}_fold{folds}_seed{seed}'

model = lgb.LGBMClassifier(**BASE_PARAMS, seed=seed)
op[config], tp[config] = custom_cv(all_features, model, folds=folds, seed=seed)

create_submission_files(tp[config], config)
# Out:
# Fold # 0: 0.78466 (  99 rounds)
# Fold # 1: 0.78916 ( 119 rounds)
# Fold # 2: 0.78338 ( 202 rounds)
# Fold # 3: 0.79775 (  49 rounds)
# Fold # 4: 0.78824 (  90 rounds)
# Fold # 5: 0.76972 ( 417 rounds)
# Fold # 6: 0.75532 (  27 rounds)
# Fold # 7: 0.76246 ( 118 rounds)
# Fold # 8: 0.75921 ( 111 rounds)
# Fold # 9: 0.77212 (  31 rounds)
#
# Avg: 0.77620 +/- 0.01368
# OOF: 0.77598
#
# CPU times: user 53.8 s, sys: 19.3 s, total: 1min 13s
# Wall time: 47.1 s

# %%
# %%time

feature_set = 'ALL'
folds = 5
seed = SEED
config = f'feat{feature_set}_fold{folds}_seed{seed}'

model = lgb.LGBMClassifier(**BASE_PARAMS, seed=seed)
op[config], tp[config] = custom_cv(all_features, model, folds=folds, seed=seed)

create_submission_files(tp[config], config)
# Out:
# Fold # 0: 0.77219 ( 106 rounds)
# Fold # 1: 0.79102 ( 109 rounds)
# Fold # 2: 0.75543 ( 116 rounds)
# Fold # 3: 0.75654 (  24 rounds)
# Fold # 4: 0.75637 (  80 rounds)
#
# Avg: 0.76631 +/- 0.01384
# OOF: 0.76620
#
# CPU times: user 23.9 s, sys: 8.1 s, total: 32.1 s
# Wall time: 20.9 s

# %%
# %%time

feature_set = 'ALL'
folds = 10
seed = 55
config = f'feat{feature_set}_fold{folds}_seed{seed}'

model = lgb.LGBMClassifier(**BASE_PARAMS, seed=seed)
op[config], tp[config] = custom_cv(all_features, model, folds=folds, seed=seed)

create_submission_files(tp[config], config)
# Out:
# Fold # 0: 0.75718 (  27 rounds)
# Fold # 1: 0.76571 (  41 rounds)
# Fold # 2: 0.76385 ( 105 rounds)
# Fold # 3: 0.77059 ( 107 rounds)
# Fold # 4: 0.76133 ( 144 rounds)
# Fold # 5: 0.79882 ( 108 rounds)
# Fold # 6: 0.80251 ( 221 rounds)
# Fold # 7: 0.79213 ( 103 rounds)
# Fold # 8: 0.78857 (  72 rounds)
# Fold # 9: 0.75287 (  82 rounds)
#
# Avg: 0.77536 +/- 0.01739
# OOF: 0.77501
#
# CPU times: user 51.5 s, sys: 17.7 s, total: 1min 9s
# Wall time: 44.2 s

# %%
# %%time

feature_set = 'ALL'
folds = 10
seed = 666
config = f'feat{feature_set}_fold{folds}_seed{seed}'

model = lgb.LGBMClassifier(**BASE_PARAMS, seed=seed)
op[config], tp[config] = custom_cv(all_features, model, folds=folds, seed=seed)

create_submission_files(tp[config], config)
# Out:
# Fold # 0: 0.78846 ( 428 rounds)
# Fold # 1: 0.80912 (  76 rounds)
# Fold # 2: 0.78363 ( 123 rounds)
# Fold # 3: 0.77128 (  38 rounds)
# Fold # 4: 0.75145 ( 109 rounds)
# Fold # 5: 0.75862 (  99 rounds)
# Fold # 6: 0.76923 (  91 rounds)
# Fold # 7: 0.77419 ( 105 rounds)
# Fold # 8: 0.77937 (  73 rounds)
# Fold # 9: 0.77101 (  90 rounds)
#
# Avg: 0.77564 +/- 0.01524
# OOF: 0.77552
#
# CPU times: user 53.2 s, sys: 19.2 s, total: 1min 12s
# Wall time: 45.8 s
