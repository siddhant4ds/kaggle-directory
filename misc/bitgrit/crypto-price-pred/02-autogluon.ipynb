# %%
# %%capture
# !pip install --upgrade autogluon ipywidgets

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
from autogluon.tabular import TabularPredictor

# %%
DATA_DIR = '/kaggle/input/bitgrit-crypto-price-prediction'

train = pd.read_csv(f'{DATA_DIR}/train.csv')
test = pd.read_csv(f'{DATA_DIR}/test.csv')
sample_sub = pd.read_csv(f'{DATA_DIR}/solution_format.csv')

# %%
train['feature_10_F_missing'] = train.feature_10_F.isna().astype('int')
test['feature_10_F_missing'] = test.feature_10_F.isna().astype('int')

# %%
TARGET = 'Target'
FEATURES = [f for f in test.columns if f not in ('ID', 'feature_10_F')]

# %%
feats_F = [f'feature_{i}_F' for i in range(1, 10)]

feats_A = [f'feature_{i}_A' for i in range(1, 10)]

CAT_FEATURES = ['TR_1_EventInd', 'TR_2_EventInd', 'TR_3_EventInd', 
                'feature_X_A', 'feature_10_A', 'feature_10_F_missing', 'feature_10_G'] \
             + feats_A + feats_F

train[CAT_FEATURES] = train[CAT_FEATURES].astype('category')
test[CAT_FEATURES] = test[CAT_FEATURES].astype('category')

# %%
# %%time

hours = 11
time_limit = 60 * 60 * hours

problem_type = 'binary'
metric = 'f1'

predictor = TabularPredictor(
    label=TARGET,
    problem_type=problem_type,
    eval_metric=metric,
    path='/kaggle/working/models')

predictor.fit(
    train[FEATURES + [TARGET]],
    time_limit=time_limit,
    presets='best_quality')
# Out:
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 39600 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: /kaggle/working/models/ds_sub_fit/sub_fit_ho.
# Running the sub-fit in a ray process to avoid memory leakage.
# Spend 9975 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 29625 seconds.
# Starting full fit now with num_stack_levels 0.
# Beginning AutoGluon training ... Time limit = 29625s
# AutoGluon will save models to "/kaggle/working/models"
# =================== System Info ===================
# AutoGluon Version:  1.1.0
# Python Version:     3.10.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Tue Dec 19 13:14:11 UTC 2023
# CPU Count:          4
# Memory Avail:       29.38 GB / 31.36 GB (93.7%)
# Disk Space Avail:   19.50 GB / 19.52 GB (99.9%)
# ===================================================
# Train Data Rows:    2660
# Train Data Columns: 76
# Label Column:       Target
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    30082.16 MB
# 	Train Data (Original)  Memory Usage: 1.10 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 5 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 25 | ['TR_1_EventInd', 'TR_2_EventInd', 'TR_3_EventInd', 'feature_10_A', 'feature_10_G', ...]
# 		('float', [])    : 51 | ['feature_10_B', 'feature_1_B', 'feature_1_C', 'feature_1_D', 'feature_1_E', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 20 | ['feature_10_A', 'feature_10_G', 'feature_1_A', 'feature_1_F', 'feature_2_A', ...]
# 		('float', [])     : 51 | ['feature_10_B', 'feature_1_B', 'feature_1_C', 'feature_1_D', 'feature_1_E', ...]
# 		('int', ['bool']) :  5 | ['TR_1_EventInd', 'TR_2_EventInd', 'TR_3_EventInd', 'feature_X_A', 'feature_10_F_missing']
# 	0.3s = Fit runtime
# 	76 features in original data used to generate 76 features in processed data.
# 	Train Data (Processed) Memory Usage: 1.10 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.41s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'f1'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 110 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 29624.59s of the 29624.57s of remaining time.
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsClassifier.fit: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsClassifier.kneighbors: running accelerated version on CPU
# 	0.7652	 = Validation score   (f1)
# 	0.68s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 29623.84s of the 29623.82s of remaining time.
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsClassifier.fit: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsClassifier.kneighbors: running accelerated version on CPU
# 	0.7686	 = Validation score   (f1)
# 	0.02s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 29623.76s of the 29623.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.07%)
# 	0.7723	 = Validation score   (f1)
# 	42.38s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 29577.0s of the 29576.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.07%)
# 	0.7887	 = Validation score   (f1)
# 	47.21s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 29525.2s of the 29525.17s of remaining time.
# 	0.7524	 = Validation score   (f1)
# 	2.23s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 29522.5s of the 29522.48s of remaining time.
# 	0.759	 = Validation score   (f1)
# 	2.57s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 29519.49s of the 29519.47s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.12%)
# 	0.769	 = Validation score   (f1)
# 	216.47s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 29298.99s of the 29298.97s of remaining time.
# 	0.7255	 = Validation score   (f1)
# 	1.63s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 29296.9s of the 29296.88s of remaining time.
# 	0.7301	 = Validation score   (f1)
# 	1.59s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 29294.85s of the 29294.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7289	 = Validation score   (f1)
# 	42.66s	 = Training   runtime
# 	0.84s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 29247.85s of the 29247.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	0.7934	 = Validation score   (f1)
# 	28.85s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 29214.09s of the 29214.07s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7275	 = Validation score   (f1)
# 	37.42s	 = Training   runtime
# 	0.89s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 29172.12s of the 29172.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.21%)
# 	0.7889	 = Validation score   (f1)
# 	90.2s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 29077.21s of the 29077.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.12%)
# 	0.7638	 = Validation score   (f1)
# 	52.51s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 29020.63s of the 29020.61s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7321	 = Validation score   (f1)
# 	59.78s	 = Training   runtime
# 	0.68s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 28956.05s of the 28956.03s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	0.7992	 = Validation score   (f1)
# 	57.84s	 = Training   runtime
# 	0.62s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 28892.66s of the 28892.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7281	 = Validation score   (f1)
# 	76.81s	 = Training   runtime
# 	1.19s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 28811.48s of the 28811.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.40%)
# 	0.7632	 = Validation score   (f1)
# 	315.23s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 28491.59s of the 28491.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.7545	 = Validation score   (f1)
# 	38.8s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 28448.1s of the 28448.07s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7288	 = Validation score   (f1)
# 	58.46s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 28385.35s of the 28385.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.79%)
# 	0.7972	 = Validation score   (f1)
# 	50.29s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 28330.08s of the 28330.05s of remaining time.
# 	0.7484	 = Validation score   (f1)
# 	2.5s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 28327.15s of the 28327.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.7605	 = Validation score   (f1)
# 	86.39s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 28236.55s of the 28236.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7295	 = Validation score   (f1)
# 	30.43s	 = Training   runtime
# 	1.3s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 28201.72s of the 28201.7s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.41%)
# 	0.7651	 = Validation score   (f1)
# 	307.27s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 27888.99s of the 27888.96s of remaining time.
# 	0.7637	 = Validation score   (f1)
# 	8.31s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 27880.27s of the 27880.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.21%)
# 	0.7807	 = Validation score   (f1)
# 	67.65s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 27808.23s of the 27808.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7363	 = Validation score   (f1)
# 	67.95s	 = Training   runtime
# 	1.06s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 27736.03s of the 27736.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	0.7895	 = Validation score   (f1)
# 	24.65s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 27705.86s of the 27705.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7462	 = Validation score   (f1)
# 	82.2s	 = Training   runtime
# 	0.72s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 27619.16s of the 27619.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.15%)
# 	0.7743	 = Validation score   (f1)
# 	37.6s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 27576.86s of the 27576.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7276	 = Validation score   (f1)
# 	46.77s	 = Training   runtime
# 	0.78s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 27525.35s of the 27525.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.7627	 = Validation score   (f1)
# 	72.37s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 27448.19s of the 27448.17s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7371	 = Validation score   (f1)
# 	84.21s	 = Training   runtime
# 	1.29s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 27359.32s of the 27359.29s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.22%)
# 	0.7923	 = Validation score   (f1)
# 	32.47s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 27320.25s of the 27320.23s of remaining time.
# 	0.7517	 = Validation score   (f1)
# 	2.5s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 27317.35s of the 27317.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.07%)
# 	0.7654	 = Validation score   (f1)
# 	151.17s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 27161.76s of the 27161.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7466	 = Validation score   (f1)
# 	68.18s	 = Training   runtime
# 	0.82s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 27089.08s of the 27089.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7248	 = Validation score   (f1)
# 	36.22s	 = Training   runtime
# 	0.88s	 = Validation runtime
# Fitting model: LightGBM_r161_BAG_L1 ... Training model for up to 27047.17s of the 27047.14s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.41%)
# 	0.7948	 = Validation score   (f1)
# 	81.57s	 = Training   runtime
# 	0.95s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 26959.65s of the 26959.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7286	 = Validation score   (f1)
# 	35.79s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Fitting model: CatBoost_r70_BAG_L1 ... Training model for up to 26918.54s of the 26918.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.12%)
# 	0.7662	 = Validation score   (f1)
# 	173.28s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 26739.92s of the 26739.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7359	 = Validation score   (f1)
# 	36.36s	 = Training   runtime
# 	0.78s	 = Validation runtime
# Fitting model: LightGBM_r196_BAG_L1 ... Training model for up to 26698.95s of the 26698.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.23%)
# 	0.7803	 = Validation score   (f1)
# 	82.89s	 = Training   runtime
# 	1.92s	 = Validation runtime
# Fitting model: RandomForest_r39_BAG_L1 ... Training model for up to 26608.46s of the 26608.44s of remaining time.
# 	0.7608	 = Validation score   (f1)
# 	8.78s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: CatBoost_r167_BAG_L1 ... Training model for up to 26599.26s of the 26599.24s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.21%)
# 	0.7678	 = Validation score   (f1)
# 	280.9s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r95_BAG_L1 ... Training model for up to 26313.78s of the 26313.76s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7368	 = Validation score   (f1)
# 	74.5s	 = Training   runtime
# 	1.04s	 = Validation runtime
# Fitting model: NeuralNetTorch_r41_BAG_L1 ... Training model for up to 26233.76s of the 26233.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7287	 = Validation score   (f1)
# 	55.67s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: XGBoost_r98_BAG_L1 ... Training model for up to 26171.67s of the 26171.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.41%)
# 	0.8019	 = Validation score   (f1)
# 	55.5s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: LightGBM_r15_BAG_L1 ... Training model for up to 26110.55s of the 26110.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.06%)
# 	0.7899	 = Validation score   (f1)
# 	46.44s	 = Training   runtime
# 	0.7s	 = Validation runtime
# Fitting model: NeuralNetTorch_r158_BAG_L1 ... Training model for up to 26059.56s of the 26059.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7466	 = Validation score   (f1)
# 	74.81s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: CatBoost_r86_BAG_L1 ... Training model for up to 25980.18s of the 25980.16s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.40%)
# 	0.7692	 = Validation score   (f1)
# 	561.26s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r37_BAG_L1 ... Training model for up to 25413.42s of the 25413.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7418	 = Validation score   (f1)
# 	46.79s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Fitting model: NeuralNetTorch_r197_BAG_L1 ... Training model for up to 25362.13s of the 25362.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7251	 = Validation score   (f1)
# 	36.54s	 = Training   runtime
# 	0.67s	 = Validation runtime
# Fitting model: CatBoost_r49_BAG_L1 ... Training model for up to 25320.59s of the 25320.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.7667	 = Validation score   (f1)
# 	42.72s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: ExtraTrees_r49_BAG_L1 ... Training model for up to 25272.46s of the 25272.44s of remaining time.
# 	0.7255	 = Validation score   (f1)
# 	2.7s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: LightGBM_r143_BAG_L1 ... Training model for up to 25269.28s of the 25269.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.28%)
# 	0.7837	 = Validation score   (f1)
# 	90.58s	 = Training   runtime
# 	0.96s	 = Validation runtime
# Fitting model: RandomForest_r127_BAG_L1 ... Training model for up to 25173.9s of the 25173.87s of remaining time.
# 	0.7615	 = Validation score   (f1)
# 	9.38s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r134_BAG_L1 ... Training model for up to 25164.08s of the 25164.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7313	 = Validation score   (f1)
# 	52.87s	 = Training   runtime
# 	0.88s	 = Validation runtime
# Fitting model: RandomForest_r34_BAG_L1 ... Training model for up to 25106.75s of the 25106.73s of remaining time.
# 	0.7391	 = Validation score   (f1)
# 	4.35s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: LightGBM_r94_BAG_L1 ... Training model for up to 25102.04s of the 25102.02s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.7618	 = Validation score   (f1)
# 	40.47s	 = Training   runtime
# 	0.75s	 = Validation runtime
# Fitting model: NeuralNetTorch_r143_BAG_L1 ... Training model for up to 25057.42s of the 25057.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7169	 = Validation score   (f1)
# 	96.44s	 = Training   runtime
# 	0.65s	 = Validation runtime
# Fitting model: CatBoost_r128_BAG_L1 ... Training model for up to 24956.01s of the 24955.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.40%)
# 	0.7599	 = Validation score   (f1)
# 	278.02s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r111_BAG_L1 ... Training model for up to 24673.23s of the 24673.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7235	 = Validation score   (f1)
# 	32.73s	 = Training   runtime
# 	0.77s	 = Validation runtime
# Fitting model: NeuralNetTorch_r31_BAG_L1 ... Training model for up to 24636.05s of the 24636.03s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7317	 = Validation score   (f1)
# 	51.14s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: ExtraTrees_r4_BAG_L1 ... Training model for up to 24578.0s of the 24577.97s of remaining time.
# 	0.7343	 = Validation score   (f1)
# 	2.15s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r65_BAG_L1 ... Training model for up to 24575.47s of the 24575.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.6909	 = Validation score   (f1)
# 	37.74s	 = Training   runtime
# 	1.0s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r88_BAG_L1 ... Training model for up to 24532.93s of the 24532.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7374	 = Validation score   (f1)
# 	39.17s	 = Training   runtime
# 	0.68s	 = Validation runtime
# Fitting model: LightGBM_r30_BAG_L1 ... Training model for up to 24487.97s of the 24487.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.19%)
# 	0.7719	 = Validation score   (f1)
# 	66.48s	 = Training   runtime
# 	1.11s	 = Validation runtime
# Fitting model: XGBoost_r49_BAG_L1 ... Training model for up to 24416.41s of the 24416.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.22%)
# 	0.7955	 = Validation score   (f1)
# 	34.28s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: CatBoost_r5_BAG_L1 ... Training model for up to 24377.7s of the 24377.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.758	 = Validation score   (f1)
# 	58.15s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: NeuralNetTorch_r87_BAG_L1 ... Training model for up to 24314.48s of the 24314.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7423	 = Validation score   (f1)
# 	56.46s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: NeuralNetTorch_r71_BAG_L1 ... Training model for up to 24252.85s of the 24252.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7267	 = Validation score   (f1)
# 	37.86s	 = Training   runtime
# 	0.61s	 = Validation runtime
# Fitting model: CatBoost_r143_BAG_L1 ... Training model for up to 24209.28s of the 24209.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.21%)
# 	0.7574	 = Validation score   (f1)
# 	65.59s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: ExtraTrees_r178_BAG_L1 ... Training model for up to 24139.01s of the 24138.99s of remaining time.
# 	0.7511	 = Validation score   (f1)
# 	2.84s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: RandomForest_r166_BAG_L1 ... Training model for up to 24135.78s of the 24135.76s of remaining time.
# 	0.7507	 = Validation score   (f1)
# 	3.14s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: XGBoost_r31_BAG_L1 ... Training model for up to 24132.07s of the 24132.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.12%)
# 	0.7824	 = Validation score   (f1)
# 	49.01s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: NeuralNetTorch_r185_BAG_L1 ... Training model for up to 24078.67s of the 24078.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7334	 = Validation score   (f1)
# 	66.54s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r160_BAG_L1 ... Training model for up to 24007.59s of the 24007.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7227	 = Validation score   (f1)
# 	57.74s	 = Training   runtime
# 	0.81s	 = Validation runtime
# Fitting model: CatBoost_r60_BAG_L1 ... Training model for up to 23944.51s of the 23944.49s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.07%)
# 	0.7606	 = Validation score   (f1)
# 	72.14s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: RandomForest_r15_BAG_L1 ... Training model for up to 23867.1s of the 23867.08s of remaining time.
# 	0.7618	 = Validation score   (f1)
# 	8.28s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: LightGBM_r135_BAG_L1 ... Training model for up to 23858.4s of the 23858.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.33%)
# 	0.7701	 = Validation score   (f1)
# 	49.5s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Fitting model: XGBoost_r22_BAG_L1 ... Training model for up to 23804.47s of the 23804.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	0.7921	 = Validation score   (f1)
# 	26.72s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r69_BAG_L1 ... Training model for up to 23773.01s of the 23772.99s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7322	 = Validation score   (f1)
# 	52.31s	 = Training   runtime
# 	1.17s	 = Validation runtime
# Fitting model: CatBoost_r6_BAG_L1 ... Training model for up to 23716.12s of the 23716.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	0.7558	 = Validation score   (f1)
# 	59.51s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r138_BAG_L1 ... Training model for up to 23651.02s of the 23651.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7255	 = Validation score   (f1)
# 	109.61s	 = Training   runtime
# 	1.02s	 = Validation runtime
# Fitting model: LightGBM_r121_BAG_L1 ... Training model for up to 23536.86s of the 23536.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.34%)
# 	0.7932	 = Validation score   (f1)
# 	78.63s	 = Training   runtime
# 	0.74s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r172_BAG_L1 ... Training model for up to 23452.84s of the 23452.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7306	 = Validation score   (f1)
# 	38.03s	 = Training   runtime
# 	1.15s	 = Validation runtime
# Fitting model: CatBoost_r180_BAG_L1 ... Training model for up to 23410.13s of the 23410.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.22%)
# 	0.7616	 = Validation score   (f1)
# 	155.09s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: NeuralNetTorch_r76_BAG_L1 ... Training model for up to 23249.92s of the 23249.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7357	 = Validation score   (f1)
# 	40.43s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: ExtraTrees_r197_BAG_L1 ... Training model for up to 23205.06s of the 23205.03s of remaining time.
# 	0.7321	 = Validation score   (f1)
# 	4.19s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: NeuralNetTorch_r121_BAG_L1 ... Training model for up to 23200.23s of the 23200.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.732	 = Validation score   (f1)
# 	128.17s	 = Training   runtime
# 	0.92s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r127_BAG_L1 ... Training model for up to 23067.5s of the 23067.47s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7315	 = Validation score   (f1)
# 	33.11s	 = Training   runtime
# 	1.04s	 = Validation runtime
# Fitting model: RandomForest_r16_BAG_L1 ... Training model for up to 23029.32s of the 23029.29s of remaining time.
# 	0.7672	 = Validation score   (f1)
# 	12.41s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r194_BAG_L1 ... Training model for up to 23016.43s of the 23016.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7284	 = Validation score   (f1)
# 	43.55s	 = Training   runtime
# 	1.17s	 = Validation runtime
# Fitting model: CatBoost_r12_BAG_L1 ... Training model for up to 22968.43s of the 22968.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.22%)
# 	0.7658	 = Validation score   (f1)
# 	121.99s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: NeuralNetTorch_r135_BAG_L1 ... Training model for up to 22840.56s of the 22840.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7391	 = Validation score   (f1)
# 	86.57s	 = Training   runtime
# 	0.61s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r4_BAG_L1 ... Training model for up to 22749.18s of the 22749.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7357	 = Validation score   (f1)
# 	48.64s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Fitting model: ExtraTrees_r126_BAG_L1 ... Training model for up to 22695.48s of the 22695.46s of remaining time.
# 	0.7542	 = Validation score   (f1)
# 	2.68s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: NeuralNetTorch_r36_BAG_L1 ... Training model for up to 22692.33s of the 22692.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7319	 = Validation score   (f1)
# 	52.59s	 = Training   runtime
# 	0.85s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r100_BAG_L1 ... Training model for up to 22635.43s of the 22635.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7183	 = Validation score   (f1)
# 	42.38s	 = Training   runtime
# 	1.11s	 = Validation runtime
# Fitting model: CatBoost_r163_BAG_L1 ... Training model for up to 22588.0s of the 22587.98s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.07%)
# 	0.7649	 = Validation score   (f1)
# 	65.67s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: CatBoost_r198_BAG_L1 ... Training model for up to 22516.75s of the 22516.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.12%)
# 	0.7651	 = Validation score   (f1)
# 	99.54s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r187_BAG_L1 ... Training model for up to 22412.54s of the 22412.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.04%)
# 	0.7348	 = Validation score   (f1)
# 	38.18s	 = Training   runtime
# 	0.82s	 = Validation runtime
# Fitting model: NeuralNetTorch_r19_BAG_L1 ... Training model for up to 22369.59s of the 22369.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7352	 = Validation score   (f1)
# 	40.07s	 = Training   runtime
# 	0.84s	 = Validation runtime
# Fitting model: XGBoost_r95_BAG_L1 ... Training model for up to 22324.07s of the 22324.05s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	0.7893	 = Validation score   (f1)
# 	30.1s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: XGBoost_r34_BAG_L1 ... Training model for up to 22287.57s of the 22287.55s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.78%)
# 	0.8019	 = Validation score   (f1)
# 	30.02s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: LightGBM_r42_BAG_L1 ... Training model for up to 22252.56s of the 22252.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.32%)
# 	0.7697	 = Validation score   (f1)
# 	46.56s	 = Training   runtime
# 	0.77s	 = Validation runtime
# Fitting model: NeuralNetTorch_r1_BAG_L1 ... Training model for up to 22200.46s of the 22200.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7381	 = Validation score   (f1)
# 	81.23s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Fitting model: NeuralNetTorch_r89_BAG_L1 ... Training model for up to 22114.74s of the 22114.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.02%)
# 	0.7402	 = Validation score   (f1)
# 	77.86s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 2962.46s of the 22032.0s of remaining time.
# 	Ensemble Weights: {'XGBoost_r34_BAG_L1': 0.375, 'KNeighborsUnif_BAG_L1': 0.125, 'XGBoost_r98_BAG_L1': 0.125, 'KNeighborsDist_BAG_L1': 0.062, 'XGBoost_r33_BAG_L1': 0.062, 'LightGBM_r161_BAG_L1': 0.062, 'LightGBM_r15_BAG_L1': 0.062, 'LightGBM_r121_BAG_L1': 0.062, 'ExtraTrees_r126_BAG_L1': 0.062}
# 	0.807	 = Validation score   (f1)
# 	2.38s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 7595.44s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/models")
# CPU times: user 5min 20s, sys: 44.9 s, total: 6min 5s
# Wall time: 4h 52min 51s

# %%
# %%time
preds = predictor.predict(test[FEATURES])
# Out:
# INFO:sklearnex: sklearn.neighbors.KNeighborsClassifier.predict_proba: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsClassifier.predict_proba: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# CPU times: user 5.87 s, sys: 167 ms, total: 6.03 s
# Wall time: 3.94 s

# %%
def create_submission_files(preds, config, notebook='02'):
    sub = sample_sub.copy()
    sub[TARGET] = preds
    sub.to_csv(f'nb{notebook}_{config}.csv', index=False)

# %%
config = f'autogluon_f1_{hours}hrs'
create_submission_files(preds, config)

# %%
# !head nb02_autogluon_f1_11hrs.csv
# Out:
# ID,Target
# 2661,1
# 2662,1
# 2663,1
# 2664,1
# 2665,1
# 2666,1
# 2667,1
# 2668,1
# 2669,1
