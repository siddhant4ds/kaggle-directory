# %% [markdown]
# # Setup

# %%
# %%capture
# !pip install --upgrade optuna_integration

# %%
import gc
gc.enable()

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

import optuna.integration.lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
from sklearn.base import clone
from lightgbm import LGBMClassifier

SEED = 2024

# %%
DATA_DIR = '/kaggle/input/ml-olympiad-predicting-earthquake-damage'

train = pd.read_csv(f'{DATA_DIR}/train.csv')
test = pd.read_csv(f'{DATA_DIR}/test.csv')
sample_sub = pd.read_csv(f'{DATA_DIR}/sample_submission.csv')

# %% [markdown]
# # Data overview

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 37 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   building_id                             4000 non-null   int64
#  1   count_floors_pre_eq                     4000 non-null   int64
#  2   age                                     4000 non-null   int64
#  3   area_percentage                         4000 non-null   int64
#  4   height_percentage                       4000 non-null   int64
#  5   land_surface_condition                  4000 non-null   object
#  6   foundation_type                         4000 non-null   object
#  7   roof_type                               4000 non-null   object
#  8   ground_floor_type                       4000 non-null   object
#  9   other_floor_type                        4000 non-null   object
#  10  position                                4000 non-null   object
#  11  plan_configuration                      4000 non-null   object
#  12  has_superstructure_adobe_mud            4000 non-null   int64
#  13  has_superstructure_mud_mortar_stone     4000 non-null   int64
#  14  has_superstructure_stone_flag           4000 non-null   int64
#  15  has_superstructure_cement_mortar_stone  4000 non-null   int64
#  16  has_superstructure_mud_mortar_brick     4000 non-null   int64
#  17  has_superstructure_cement_mortar_brick  4000 non-null   int64
#  18  has_superstructure_timber               4000 non-null   int64
#  19  has_superstructure_bamboo               4000 non-null   int64
#  20  has_superstructure_rc_non_engineered    4000 non-null   int64
#  21  has_superstructure_rc_engineered        4000 non-null   int64
#  22  has_superstructure_other                4000 non-null   int64
#  23  legal_ownership_status                  4000 non-null   object
#  24  count_families                          4000 non-null   int64
#  25  has_secondary_use                       4000 non-null   int64
#  26  has_secondary_use_agriculture           4000 non-null   int64
#  27  has_secondary_use_hotel                 4000 non-null   int64
#  28  has_secondary_use_rental                4000 non-null   int64
#  29  has_secondary_use_institution           4000 non-null   int64
#  30  has_secondary_use_school                4000 non-null   int64
#  31  has_secondary_use_industry              4000 non-null   int64
#  32  has_secondary_use_health_post           4000 non-null   int64
#  33  has_secondary_use_gov_office            4000 non-null   int64
#  34  has_secondary_use_use_police            4000 non-null   int64
#  35  has_secondary_use_other                 4000 non-null   int64
#  36  damage_grade                            4000 non-null   int64
# dtypes: int64(29), object(8)
# memory usage: 1.1+ MB

# %%
train.shape, test.shape, sample_sub.shape
# Out:
# ((4000, 37), (1000, 36), (1000, 2))

# %%
train.isna().sum().sum(), test.isna().sum().sum()
# Out:
# (0, 0)

# %%
TARGET = 'damage_grade'
train[TARGET].value_counts(normalize=True)
# Out:
# damage_grade
# 2    0.49200
# 3    0.32575
# 1    0.18225
# Name: proportion, dtype: float64

# %%
train[TARGET] = train[TARGET] - 1  # reversed in postprocessing
train[TARGET].value_counts(normalize=True)
# Out:
# damage_grade
# 1    0.49200
# 2    0.32575
# 0    0.18225
# Name: proportion, dtype: float64

# %%
train.nunique()
# Out:
# building_id                               4000
# count_floors_pre_eq                          8
# age                                        100
# area_percentage                             39
# height_percentage                           15
# land_surface_condition                       3
# foundation_type                              5
# roof_type                                    3
# ground_floor_type                            5
# other_floor_type                             4
# position                                     4
# plan_configuration                          10
# has_superstructure_adobe_mud                 2
# has_superstructure_mud_mortar_stone          2
# has_superstructure_stone_flag                2
# has_superstructure_cement_mortar_stone       2
# has_superstructure_mud_mortar_brick          2
# has_superstructure_cement_mortar_brick       2
# has_superstructure_timber                    2
# has_superstructure_bamboo                    2
# has_superstructure_rc_non_engineered         2
# has_superstructure_rc_engineered             2
# has_superstructure_other                     2
# legal_ownership_status                       4
# count_families                              10
# has_secondary_use                            2
# has_secondary_use_agriculture                2
# has_secondary_use_hotel                      2
# has_secondary_use_rental                     2
# has_secondary_use_institution                2
# has_secondary_use_school                     2
# has_secondary_use_industry                   2
# has_secondary_use_health_post                2
# has_secondary_use_gov_office                 2
# has_secondary_use_use_police                 2
# has_secondary_use_other                      2
# damage_grade                                 3
# dtype: int64

# %% [markdown]
# # Data Preparation

# %%
train = train.drop('building_id', axis=1)
test = test.drop('building_id', axis=1)

# %%
train = pd.get_dummies(train, dtype='int8')
test = pd.get_dummies(test, dtype='int8')

# %%
features = list(test.columns)
num_features = ['count_floors_pre_eq', 'age', 'area_percentage', 'height_percentage', 'count_families']
cat_features = [f for f in features if f not in num_features]

# %%
# LightGBM dataset
dtrain = lgb.Dataset(
    data=train[features],
    label=train[TARGET],
    feature_name=features,
    categorical_feature=cat_features)

# %% [markdown]
# # Hyperparameter tuning

# %%
base_params = {
    'objective': 'multiclass_ova',
    'num_class': 3,
    'is_unbalance': True,
    'metric': 'multi_error',
    'learning_rate': 0.005,
    'boosting_type': 'gbdt',
    'force_row_wise': True,
    'verbosity': -1,
    'n_jobs': -1,
    'deterministic': True,
    'random_state': SEED
}

# %%
early_stopping = lgb.early_stopping(
    stopping_rounds=100,
    first_metric_only=True,
    verbose=False,
    min_delta=1e-4)

# %%
BUDGET = 60 * 60 * 1.5
NUM_FOLDS = 7

tuner = lgb.LightGBMTunerCV(
    time_budget=BUDGET,
    optuna_seed=SEED,
    params=base_params,
    train_set=dtrain,
    num_boost_round=5000,
    nfold=NUM_FOLDS,
    stratified=True,
    shuffle=True,
    seed=SEED,
    feature_name=features,
    categorical_feature=cat_features,
    callbacks=[early_stopping])
# Out:
# [I 2024-04-20 04:06:57,021] A new study created in memory with name: no-name-3f4e57bf-806c-465a-8f1e-82fc4cac59a2

# %%
# %%time
tuner.run()
# Out:
# feature_fraction, val_score: 0.449498:  14%|#4        | 1/7 [00:40<04:02, 40.46s/it][I 2024-04-20 04:07:37,500] Trial 0 finished with value: 0.4494984000237941 and parameters: {'feature_fraction': 0.5}. Best is trial 0 with value: 0.4494984000237941.
# feature_fraction, val_score: 0.449498:  29%|##8       | 2/7 [01:13<02:59, 35.89s/it][I 2024-04-20 04:08:10,186] Trial 1 finished with value: 0.4519919660024739 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 0 with value: 0.4494984000237941.
# feature_fraction, val_score: 0.449498:  43%|####2     | 3/7 [01:49<02:24, 36.10s/it][I 2024-04-20 04:08:46,550] Trial 2 finished with value: 0.4504930271129921 and parameters: {'feature_fraction': 0.7}. Best is trial 0 with value: 0.4494984000237941.
# feature_fraction, val_score: 0.449498:  57%|#####7    | 4/7 [02:24<01:47, 35.67s/it][I 2024-04-20 04:09:21,564] Trial 3 finished with value: 0.44974377636374124 and parameters: {'feature_fraction': 0.8}. Best is trial 0 with value: 0.4494984000237941.
# feature_fraction, val_score: 0.449498:  71%|#######1  | 5/7 [02:56<01:08, 34.46s/it][I 2024-04-20 04:09:53,875] Trial 4 finished with value: 0.453498777929601 and parameters: {'feature_fraction': 1.0}. Best is trial 0 with value: 0.4494984000237941.
# feature_fraction, val_score: 0.449498:  86%|########5 | 6/7 [03:36<00:36, 36.15s/it][I 2024-04-20 04:10:33,306] Trial 5 finished with value: 0.45024240208128125 and parameters: {'feature_fraction': 0.6}. Best is trial 0 with value: 0.4494984000237941.
# feature_fraction, val_score: 0.449498: 100%|##########| 7/7 [04:17<00:00, 37.69s/it][I 2024-04-20 04:11:14,152] Trial 6 finished with value: 0.4520011512130601 and parameters: {'feature_fraction': 0.4}. Best is trial 0 with value: 0.4494984000237941.
# feature_fraction, val_score: 0.449498: 100%|##########| 7/7 [04:17<00:00, 36.73s/it]
# num_leaves, val_score: 0.447242:   5%|5         | 1/20 [01:48<34:16, 108.24s/it][I 2024-04-20 04:13:02,397] Trial 7 finished with value: 0.4472423373474162 and parameters: {'num_leaves': 151}. Best is trial 7 with value: 0.4472423373474162.
# num_leaves, val_score: 0.447242:  10%|#         | 2/20 [03:36<32:31, 108.43s/it][I 2024-04-20 04:14:50,966] Trial 8 finished with value: 0.4472423373474162 and parameters: {'num_leaves': 180}. Best is trial 7 with value: 0.4472423373474162.
# num_leaves, val_score: 0.447242:  15%|#5        | 3/20 [04:34<24:07, 85.15s/it] [I 2024-04-20 04:15:48,402] Trial 9 finished with value: 0.4502467759910842 and parameters: {'num_leaves': 49}. Best is trial 7 with value: 0.4472423373474162.
# num_leaves, val_score: 0.447242:  20%|##        | 4/20 [06:24<25:20, 95.04s/it][I 2024-04-20 04:17:38,607] Trial 10 finished with value: 0.4472423373474162 and parameters: {'num_leaves': 224}. Best is trial 7 with value: 0.4472423373474162.
# num_leaves, val_score: 0.447242:  25%|##5       | 5/20 [08:16<25:17, 101.13s/it][I 2024-04-20 04:19:30,547] Trial 11 finished with value: 0.4472423373474162 and parameters: {'num_leaves': 173}. Best is trial 7 with value: 0.4472423373474162.
# num_leaves, val_score: 0.447242:  30%|###       | 6/20 [10:13<24:52, 106.60s/it][I 2024-04-20 04:21:27,764] Trial 12 finished with value: 0.4474920875971664 and parameters: {'num_leaves': 128}. Best is trial 7 with value: 0.4472423373474162.
# num_leaves, val_score: 0.447242:  35%|###5      | 7/20 [12:09<23:45, 109.66s/it][I 2024-04-20 04:23:23,723] Trial 13 finished with value: 0.4472423373474162 and parameters: {'num_leaves': 143}. Best is trial 7 with value: 0.4472423373474162.
# num_leaves, val_score: 0.447242:  40%|####      | 8/20 [13:59<21:55, 109.63s/it][I 2024-04-20 04:25:13,281] Trial 14 finished with value: 0.4472423373474162 and parameters: {'num_leaves': 207}. Best is trial 7 with value: 0.4472423373474162.
# num_leaves, val_score: 0.446746:  45%|####5     | 9/20 [15:33<19:12, 104.81s/it][I 2024-04-20 04:26:47,487] Trial 15 finished with value: 0.446746335975758 and parameters: {'num_leaves': 92}. Best is trial 15 with value: 0.446746335975758.
# num_leaves, val_score: 0.446746:  50%|#####     | 10/20 [16:47<15:52, 95.23s/it][I 2024-04-20 04:28:01,263] Trial 16 finished with value: 0.4494962130688926 and parameters: {'num_leaves': 71}. Best is trial 15 with value: 0.446746335975758.
# num_leaves, val_score: 0.446746:  55%|#####5    | 11/20 [18:20<14:12, 94.71s/it][I 2024-04-20 04:29:34,799] Trial 17 finished with value: 0.4472462738662389 and parameters: {'num_leaves': 95}. Best is trial 15 with value: 0.446746335975758.
# num_leaves, val_score: 0.446746:  60%|######    | 12/20 [18:48<09:53, 74.23s/it][I 2024-04-20 04:30:02,193] Trial 18 finished with value: 0.45049915058671625 and parameters: {'num_leaves': 19}. Best is trial 15 with value: 0.446746335975758.
# num_leaves, val_score: 0.446746:  65%|######5   | 13/20 [20:28<09:34, 82.14s/it][I 2024-04-20 04:31:42,535] Trial 19 finished with value: 0.446995648834528 and parameters: {'num_leaves': 114}. Best is trial 15 with value: 0.446746335975758.
# num_leaves, val_score: 0.446495:  70%|#######   | 14/20 [22:05<08:40, 86.78s/it][I 2024-04-20 04:33:20,018] Trial 20 finished with value: 0.44649483616208663 and parameters: {'num_leaves': 104}. Best is trial 20 with value: 0.44649483616208663.
# num_leaves, val_score: 0.446494:  75%|#######5  | 15/20 [23:44<07:31, 90.28s/it][I 2024-04-20 04:34:58,432] Trial 21 finished with value: 0.446493961380126 and parameters: {'num_leaves': 103}. Best is trial 21 with value: 0.446493961380126.
# num_leaves, val_score: 0.446494:  80%|########  | 16/20 [25:04<05:49, 87.28s/it][I 2024-04-20 04:36:18,723] Trial 22 finished with value: 0.44824702442916103 and parameters: {'num_leaves': 76}. Best is trial 21 with value: 0.446493961380126.
# num_leaves, val_score: 0.446494:  85%|########5 | 17/20 [26:41<04:30, 90.07s/it][I 2024-04-20 04:37:55,304] Trial 23 finished with value: 0.44749602411598915 and parameters: {'num_leaves': 101}. Best is trial 21 with value: 0.446493961380126.
# num_leaves, val_score: 0.446494:  90%|######### | 18/20 [27:25<02:32, 76.36s/it][I 2024-04-20 04:38:39,747] Trial 24 finished with value: 0.44974508853668216 and parameters: {'num_leaves': 35}. Best is trial 21 with value: 0.446493961380126.
# num_leaves, val_score: 0.446494:  95%|#########5| 19/20 [28:38<01:15, 75.27s/it][I 2024-04-20 04:39:52,480] Trial 25 finished with value: 0.4494975252418335 and parameters: {'num_leaves': 72}. Best is trial 21 with value: 0.446493961380126.
# num_leaves, val_score: 0.446245: 100%|##########| 20/20 [30:16<00:00, 82.13s/it][I 2024-04-20 04:41:30,586] Trial 26 finished with value: 0.4462450859123363 and parameters: {'num_leaves': 107}. Best is trial 26 with value: 0.4462450859123363.
# num_leaves, val_score: 0.446245: 100%|##########| 20/20 [30:16<00:00, 90.82s/it]
# bagging, val_score: 0.442748:  10%|#         | 1/10 [01:39<14:51, 99.03s/it][I 2024-04-20 04:43:09,621] Trial 27 finished with value: 0.4427477076338723 and parameters: {'bagging_fraction': 0.5736183015264869, 'bagging_freq': 3}. Best is trial 27 with value: 0.4427477076338723.
# bagging, val_score: 0.442748:  20%|##        | 2/10 [03:41<15:03, 112.91s/it][I 2024-04-20 04:45:12,255] Trial 28 finished with value: 0.44499414770868356 and parameters: {'bagging_fraction': 0.569487074468038, 'bagging_freq': 3}. Best is trial 27 with value: 0.4427477076338723.
# bagging, val_score: 0.442748:  30%|###       | 3/10 [05:38<13:24, 114.93s/it][I 2024-04-20 04:47:09,583] Trial 29 finished with value: 0.44699827318040974 and parameters: {'bagging_fraction': 0.5372094626831886, 'bagging_freq': 3}. Best is trial 27 with value: 0.4427477076338723.
# bagging, val_score: 0.442748:  40%|####      | 4/10 [07:39<11:42, 117.16s/it][I 2024-04-20 04:49:10,166] Trial 30 finished with value: 0.44849327555106894 and parameters: {'bagging_fraction': 0.5950216093504856, 'bagging_freq': 3}. Best is trial 27 with value: 0.4427477076338723.
# bagging, val_score: 0.442748:  50%|#####     | 5/10 [09:56<10:21, 124.24s/it][I 2024-04-20 04:51:26,947] Trial 31 finished with value: 0.4474955867250087 and parameters: {'bagging_fraction': 0.7231829919101438, 'bagging_freq': 3}. Best is trial 27 with value: 0.4427477076338723.
# bagging, val_score: 0.442748:  60%|######    | 6/10 [11:26<07:30, 112.59s/it][I 2024-04-20 04:52:56,927] Trial 32 finished with value: 0.4500009622601567 and parameters: {'bagging_fraction': 0.4245024832862044, 'bagging_freq': 7}. Best is trial 27 with value: 0.4427477076338723.
# bagging, val_score: 0.442748:  70%|#######   | 7/10 [13:02<05:21, 107.21s/it][I 2024-04-20 04:54:33,057] Trial 33 finished with value: 0.4487447753647404 and parameters: {'bagging_fraction': 0.8401507989127597, 'bagging_freq': 1}. Best is trial 27 with value: 0.4427477076338723.
# bagging, val_score: 0.442748:  80%|########  | 8/10 [14:18<03:14, 97.13s/it] [I 2024-04-20 04:55:48,606] Trial 34 finished with value: 0.44724758603917975 and parameters: {'bagging_fraction': 0.6253008172829442, 'bagging_freq': 5}. Best is trial 27 with value: 0.4427477076338723.
# bagging, val_score: 0.442748:  90%|######### | 9/10 [15:17<01:25, 85.49s/it][I 2024-04-20 04:56:48,489] Trial 35 finished with value: 0.4437484581967945 and parameters: {'bagging_fraction': 0.459893667751829, 'bagging_freq': 5}. Best is trial 27 with value: 0.4427477076338723.
# bagging, val_score: 0.442748: 100%|##########| 10/10 [16:17<00:00, 77.41s/it][I 2024-04-20 04:57:47,804] Trial 36 finished with value: 0.44824527486523985 and parameters: {'bagging_fraction': 0.44111362197860376, 'bagging_freq': 5}. Best is trial 27 with value: 0.4427477076338723.
# bagging, val_score: 0.442748: 100%|##########| 10/10 [16:17<00:00, 97.72s/it]
# feature_fraction_stage2, val_score: 0.442748:  17%|#6        | 1/6 [01:12<06:00, 72.10s/it][I 2024-04-20 04:58:59,909] Trial 37 finished with value: 0.4439968962736038 and parameters: {'feature_fraction': 0.484}. Best is trial 37 with value: 0.4439968962736038.
# feature_fraction_stage2, val_score: 0.442748:  33%|###3      | 2/6 [02:20<04:40, 70.13s/it][I 2024-04-20 05:00:08,664] Trial 38 finished with value: 0.4469952114435477 and parameters: {'feature_fraction': 0.45199999999999996}. Best is trial 37 with value: 0.4439968962736038.
# feature_fraction_stage2, val_score: 0.442748:  50%|#####     | 3/6 [03:26<03:24, 68.25s/it][I 2024-04-20 05:01:14,670] Trial 39 finished with value: 0.4497512120104064 and parameters: {'feature_fraction': 0.42}. Best is trial 37 with value: 0.4439968962736038.
# feature_fraction_stage2, val_score: 0.442748:  67%|######6   | 4/6 [04:38<02:19, 69.55s/it][I 2024-04-20 05:02:26,227] Trial 40 finished with value: 0.44649877268090926 and parameters: {'feature_fraction': 0.516}. Best is trial 37 with value: 0.4439968962736038.
# feature_fraction_stage2, val_score: 0.442748:  83%|########3 | 5/6 [05:58<01:13, 73.39s/it][I 2024-04-20 05:03:46,420] Trial 41 finished with value: 0.4472453990842782 and parameters: {'feature_fraction': 0.5479999999999999}. Best is trial 37 with value: 0.4439968962736038.
# feature_fraction_stage2, val_score: 0.442748: 100%|##########| 6/6 [08:03<00:00, 90.75s/it][I 2024-04-20 05:05:50,861] Trial 42 finished with value: 0.44749821107089055 and parameters: {'feature_fraction': 0.58}. Best is trial 37 with value: 0.4439968962736038.
# feature_fraction_stage2, val_score: 0.442748: 100%|##########| 6/6 [08:03<00:00, 80.51s/it]
# regularization_factors, val_score: 0.442748:   5%|5         | 1/20 [01:48<34:25, 108.70s/it][I 2024-04-20 05:07:39,572] Trial 43 finished with value: 0.44474570963187426 and parameters: {'lambda_l1': 4.020448680588366e-06, 'lambda_l2': 5.063045298563952e-06}. Best is trial 43 with value: 0.44474570963187426.
# regularization_factors, val_score: 0.442748:  10%|#         | 2/20 [03:36<32:31, 108.42s/it][I 2024-04-20 05:09:27,799] Trial 44 finished with value: 0.44449508460016346 and parameters: {'lambda_l1': 3.485829307948253e-06, 'lambda_l2': 2.816150674907995e-06}. Best is trial 44 with value: 0.44449508460016346.
# regularization_factors, val_score: 0.442748:  15%|#5        | 3/20 [05:21<30:14, 106.75s/it][I 2024-04-20 05:11:12,546] Trial 45 finished with value: 0.4442462091323737 and parameters: {'lambda_l1': 1.1432519221803943e-06, 'lambda_l2': 3.427460308826897e-06}. Best is trial 45 with value: 0.4442462091323737.
# regularization_factors, val_score: 0.442748:  20%|##        | 4/20 [07:04<28:05, 105.34s/it][I 2024-04-20 05:12:55,732] Trial 46 finished with value: 0.4449954598816245 and parameters: {'lambda_l1': 1.4798941201571672e-06, 'lambda_l2': 1.8788704117504469e-06}. Best is trial 45 with value: 0.4442462091323737.
# regularization_factors, val_score: 0.442748:  25%|##5       | 5/20 [08:26<24:10, 96.68s/it] [I 2024-04-20 05:14:17,050] Trial 47 finished with value: 0.4444955219911436 and parameters: {'lambda_l1': 4.17220162674358e-08, 'lambda_l2': 1.646305317326751e-05}. Best is trial 45 with value: 0.4442462091323737.
# regularization_factors, val_score: 0.442748:  30%|###       | 6/20 [09:04<17:53, 76.69s/it][I 2024-04-20 05:14:54,932] Trial 48 finished with value: 0.44924908716502415 and parameters: {'lambda_l1': 0.010250006526390066, 'lambda_l2': 7.710115902201558}. Best is trial 45 with value: 0.4442462091323737.
# regularization_factors, val_score: 0.442748:  35%|###5      | 7/20 [10:15<16:12, 74.81s/it][I 2024-04-20 05:16:05,874] Trial 49 finished with value: 0.4442444595684526 and parameters: {'lambda_l1': 8.547870548176594e-05, 'lambda_l2': 2.0823676487991944e-08}. Best is trial 49 with value: 0.4442444595684526.
# regularization_factors, val_score: 0.442748:  40%|####      | 8/20 [11:33<15:09, 75.83s/it][I 2024-04-20 05:17:23,875] Trial 50 finished with value: 0.4464965857260078 and parameters: {'lambda_l1': 0.0007100416273244825, 'lambda_l2': 4.003274625700233e-08}. Best is trial 49 with value: 0.4442444595684526.
# regularization_factors, val_score: 0.442748:  45%|####5     | 9/20 [12:47<13:49, 75.38s/it][I 2024-04-20 05:18:38,287] Trial 51 finished with value: 0.44349608360116244 and parameters: {'lambda_l1': 8.995637947590373e-06, 'lambda_l2': 4.007595688381708e-08}. Best is trial 51 with value: 0.44349608360116244.
# regularization_factors, val_score: 0.442748:  50%|#####     | 10/20 [13:15<10:08, 60.84s/it][I 2024-04-20 05:19:06,574] Trial 52 finished with value: 0.44875221101140544 and parameters: {'lambda_l1': 2.7904670004372263, 'lambda_l2': 1.2079111887924051e-08}. Best is trial 51 with value: 0.44349608360116244.
# regularization_factors, val_score: 0.442748:  55%|#####5    | 11/20 [14:24<09:29, 63.28s/it][I 2024-04-20 05:20:15,395] Trial 53 finished with value: 0.4454932108172038 and parameters: {'lambda_l1': 6.814797656341544e-05, 'lambda_l2': 1.2571436678436284e-08}. Best is trial 51 with value: 0.44349608360116244.
# regularization_factors, val_score: 0.442748:  60%|######    | 12/20 [15:41<08:59, 67.42s/it][I 2024-04-20 05:21:32,260] Trial 54 finished with value: 0.44774708653868023 and parameters: {'lambda_l1': 2.694953748541713e-08, 'lambda_l2': 0.002405022701030116}. Best is trial 51 with value: 0.44349608360116244.
# regularization_factors, val_score: 0.442748:  65%|######5   | 13/20 [16:55<08:06, 69.55s/it][I 2024-04-20 05:22:46,713] Trial 55 finished with value: 0.4457442732398949 and parameters: {'lambda_l1': 0.00011084548052357557, 'lambda_l2': 2.7871138591251096e-07}. Best is trial 51 with value: 0.44349608360116244.
# regularization_factors, val_score: 0.442748:  70%|#######   | 14/20 [18:05<06:56, 69.44s/it][I 2024-04-20 05:23:55,888] Trial 56 finished with value: 0.4449967720545654 and parameters: {'lambda_l1': 1.0154546185641466e-06, 'lambda_l2': 0.00029653846009023246}. Best is trial 51 with value: 0.44349608360116244.
# regularization_factors, val_score: 0.442748:  75%|#######5  | 15/20 [19:10<05:41, 68.27s/it][I 2024-04-20 05:25:01,447] Trial 57 finished with value: 0.4477462117567197 and parameters: {'lambda_l1': 0.005873522642945826, 'lambda_l2': 2.466907565299916e-07}. Best is trial 51 with value: 0.44349608360116244.
# regularization_factors, val_score: 0.442748:  80%|########  | 16/20 [20:20<04:35, 68.75s/it][I 2024-04-20 05:26:11,327] Trial 58 finished with value: 0.4447439600679531 and parameters: {'lambda_l1': 2.7525340987196332e-05, 'lambda_l2': 7.872919522225722e-05}. Best is trial 51 with value: 0.44349608360116244.
# regularization_factors, val_score: 0.442748:  85%|########5 | 17/20 [21:32<03:28, 69.61s/it][I 2024-04-20 05:27:22,923] Trial 59 finished with value: 0.44374408428699147 and parameters: {'lambda_l1': 9.224917593036845e-08, 'lambda_l2': 2.3344030433043417e-07}. Best is trial 51 with value: 0.44349608360116244.
# regularization_factors, val_score: 0.442748:  90%|######### | 18/20 [22:41<02:19, 69.51s/it][I 2024-04-20 05:28:32,203] Trial 60 finished with value: 0.44299527092872104 and parameters: {'lambda_l1': 1.6032723775654996e-08, 'lambda_l2': 1.7151647639293982e-07}. Best is trial 60 with value: 0.44299527092872104.
# regularization_factors, val_score: 0.442748:  95%|#########5| 19/20 [23:47<01:08, 68.61s/it][I 2024-04-20 05:29:38,711] Trial 61 finished with value: 0.4434938966462609 and parameters: {'lambda_l1': 1.0228582906958246e-08, 'lambda_l2': 1.6112515792292164e-07}. Best is trial 60 with value: 0.44299527092872104.
# regularization_factors, val_score: 0.442748: 100%|##########| 20/20 [24:58<00:00, 69.11s/it][I 2024-04-20 05:30:49,005] Trial 62 finished with value: 0.44324458378749093 and parameters: {'lambda_l1': 1.5617597292085182e-08, 'lambda_l2': 3.142681055483359e-07}. Best is trial 60 with value: 0.44299527092872104.
# regularization_factors, val_score: 0.442748: 100%|##########| 20/20 [24:58<00:00, 74.91s/it]
# min_child_samples, val_score: 0.442748:  20%|##        | 1/5 [01:02<04:08, 62.22s/it][I 2024-04-20 05:31:51,229] Trial 63 finished with value: 0.44875221101140544 and parameters: {'min_child_samples': 25}. Best is trial 63 with value: 0.44875221101140544.
# min_child_samples, val_score: 0.442748:  40%|####      | 2/5 [02:59<04:43, 94.61s/it][I 2024-04-20 05:33:48,524] Trial 64 finished with value: 0.4444928976452619 and parameters: {'min_child_samples': 10}. Best is trial 64 with value: 0.4444928976452619.
# min_child_samples, val_score: 0.442748:  60%|######    | 3/5 [05:23<03:54, 117.08s/it][I 2024-04-20 05:36:12,344] Trial 65 finished with value: 0.4447417731130515 and parameters: {'min_child_samples': 5}. Best is trial 64 with value: 0.4444928976452619.
# min_child_samples, val_score: 0.442748:  80%|########  | 4/5 [05:42<01:18, 78.34s/it] [I 2024-04-20 05:36:31,303] Trial 66 finished with value: 0.4494979626328138 and parameters: {'min_child_samples': 100}. Best is trial 64 with value: 0.4444928976452619.
# min_child_samples, val_score: 0.442748: 100%|##########| 5/5 [06:11<00:00, 60.78s/it][I 2024-04-20 05:37:00,942] Trial 67 finished with value: 0.44949927480575463 and parameters: {'min_child_samples': 50}. Best is trial 64 with value: 0.4444928976452619.
# min_child_samples, val_score: 0.442748: 100%|##########| 5/5 [06:11<00:00, 74.39s/it]
# CPU times: user 44min 4s, sys: 55min 40s, total: 1h 39min 44s
# Wall time: 1h 30min 3s

# %%
print(f'Best score: {tuner.best_score:.5f}')
print(f'Best hyperparameters:')
for k, v in tuner.best_params.items():
    print(f'{k:20} - {v}')
# Out:
# Best score: 0.44275
# Best hyperparameters:
# objective            - multiclass_ova
# num_class            - 3
# is_unbalance         - True
# metric               - multi_error
# learning_rate        - 0.005
# boosting_type        - gbdt
# force_row_wise       - True
# verbosity            - -1
# n_jobs               - -1
# deterministic        - True
# random_state         - 2024
# feature_pre_filter   - False
# lambda_l1            - 0.0
# lambda_l2            - 0.0
# num_leaves           - 107
# feature_fraction     - 0.5
# bagging_fraction     - 0.5736183015264869
# bagging_freq         - 3
# min_child_samples    - 20

# %% [markdown]
# # Cross-validation

# %%
def comp_metric(y_true, y_pred):
    return f1_score(y_true, y_pred, average='macro')

def custom_cv(estimator, seed=SEED, verbose=True):
    X_test = test[features]
    
    oof_preds, test_preds = {}, {}
    scores = []

    cv = StratifiedKFold(n_splits=NUM_FOLDS, shuffle=True, random_state=seed)
    for fold, (train_ids, val_ids) in enumerate(cv.split(train, train[TARGET])):
        X_train, y_train = train[features].iloc[train_ids], train[TARGET].iloc[train_ids]
        X_val, y_val = train[features].iloc[val_ids], train[TARGET].iloc[val_ids]
        
        model = clone(estimator)
        model.fit(
            X_train, y_train,
            eval_set=[(X_val, y_val)],
            callbacks=[early_stopping])

        val_preds = model.predict(X_val)
        oof_preds.update(dict(zip(val_ids, val_preds)))
        test_preds[f'fold{fold}'] = model.predict(X_test)

        score = comp_metric(y_val, val_preds)
        scores.append(score)
        if verbose:
            print(f'Fold #{fold:>2}: {score:.5f} ({model.best_iteration_:>4} rounds)')
        _ = gc.collect()

    test_preds = pd.DataFrame.from_dict(test_preds)
    test_preds['mode'] = test_preds.mode(axis=1)[0].astype('int') # mode of fold-wise predictions
    
    oof_preds = pd.Series(oof_preds).sort_index()
    print(f'\nAvg score: {np.mean(scores):.5f} +/- {np.std(scores):.5f}')
    print(f'OOF score: {comp_metric(train[TARGET], oof_preds):.5f}\n')
    
    return oof_preds, test_preds

# %%
# %%time
model = LGBMClassifier(**tuner.best_params, n_estimators=5000)
op, tp = custom_cv(model)
# Out:
# Fold # 0: 0.56220 ( 173 rounds)
# Fold # 1: 0.53801 ( 157 rounds)
# Fold # 2: 0.54660 ( 210 rounds)
# Fold # 3: 0.50799 ( 142 rounds)
# Fold # 4: 0.45906 ( 106 rounds)
# Fold # 5: 0.54353 ( 142 rounds)
# Fold # 6: 0.57510 ( 195 rounds)
#
# Avg score: 0.53321 +/- 0.03593
# OOF score: 0.53977
#
# CPU times: user 9.68 s, sys: 0 ns, total: 9.68 s
# Wall time: 9.68 s

# %%
def create_submission_files(preds, notebook='00'):
    for col in preds.columns:
        sub = sample_sub.copy()
        # inverse transform for the target
        sub[TARGET] = (preds[col] + 1)
        sub.to_csv(f'nb{notebook}_{col}.csv', index=False)

# %%
create_submission_files(tp)
