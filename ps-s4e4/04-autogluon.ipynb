# %%
# %%capture
# !pip install --upgrade autogluon ipywidgets

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
from autogluon.tabular import TabularPredictor

# %%
DATA_DIR = '/kaggle/input/playground-series-s4e4'

train = pd.read_csv(f'{DATA_DIR}/train.csv')
test = pd.read_csv(f'{DATA_DIR}/test.csv')
sample_sub = pd.read_csv(f'{DATA_DIR}/sample_submission.csv')

# %%
train = train.drop('id', axis=1)
test = test.drop('id', axis=1)

# %%
TARGET = 'Rings'
features = [f for f in test.columns]

# %%
train[TARGET] = np.log1p(train[TARGET])

# %%
time_limit = 60 * 60 * 10
metric = 'rmse'

predictor = TabularPredictor(
    label=TARGET, 
    eval_metric=metric,
    path='/kaggle/working/models')

predictor.fit(
    train,
    time_limit=time_limit,
    presets='best_quality')
# Out:
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 36000 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: /kaggle/working/models/ds_sub_fit/sub_fit_ho.
# Running the sub-fit in a ray process to avoid memory leakage.
# Spend 9191 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 26809 seconds.
# Starting full fit now with num_stack_levels 1.
# Beginning AutoGluon training ... Time limit = 26809s
# AutoGluon will save models to "/kaggle/working/models"
# =================== System Info ===================
# AutoGluon Version:  1.1.0
# Python Version:     3.10.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Tue Dec 19 13:14:11 UTC 2023
# CPU Count:          4
# Memory Avail:       29.00 GB / 31.36 GB (92.5%)
# Disk Space Avail:   19.50 GB / 19.52 GB (99.9%)
# ===================================================
# Train Data Rows:    90615
# Train Data Columns: 8
# Label Column:       Rings
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    29700.11 MB
# 	Train Data (Original)  Memory Usage: 9.85 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 7 | ['Length', 'Diameter', 'Height', 'Whole weight', 'Whole weight.1', ...]
# 		('object', []) : 1 | ['Sex']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 1 | ['Sex']
# 		('float', [])    : 7 | ['Length', 'Diameter', 'Height', 'Whole weight', 'Whole weight.1', ...]
# 	0.4s = Fit runtime
# 	8 features in original data used to generate 8 features in processed data.
# 	Train Data (Processed) Memory Usage: 4.93 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.47s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 17867.88s of the 26808.5s of remaining time.
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsRegressor.fit: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsRegressor.fit: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsRegressor.fit: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsRegressor.fit: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsRegressor.predict: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsRegressor.kneighbors: running accelerated version on CPU
# 	-0.1637	 = Validation score   (-root_mean_squared_error)
# 	0.75s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 17866.27s of the 26806.89s of remaining time.
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsRegressor.fit: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsRegressor.fit: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsRegressor.fit: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsRegressor.fit: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsRegressor.predict: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsRegressor.kneighbors: running accelerated version on CPU
# 	-0.164	 = Validation score   (-root_mean_squared_error)
# 	0.12s	 = Training   runtime
# 	0.81s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 17865.28s of the 26805.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	-0.1494	 = Validation score   (-root_mean_squared_error)
# 	962.81s	 = Training   runtime
# 	716.03s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 16861.58s of the 25802.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	-0.1485	 = Validation score   (-root_mean_squared_error)
# 	82.55s	 = Training   runtime
# 	22.34s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 16773.94s of the 25714.56s of remaining time.
# 	-0.1519	 = Validation score   (-root_mean_squared_error)
# 	62.09s	 = Training   runtime
# 	4.84s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 16704.46s of the 25645.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	-0.1482	 = Validation score   (-root_mean_squared_error)
# 	1040.06s	 = Training   runtime
# 	0.64s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 15660.58s of the 24601.2s of remaining time.
# 	-0.1507	 = Validation score   (-root_mean_squared_error)
# 	17.64s	 = Training   runtime
# 	4.41s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 15636.19s of the 24576.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.18%)
# 	-0.1511	 = Validation score   (-root_mean_squared_error)
# 	423.03s	 = Training   runtime
# 	2.99s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 15208.64s of the 24149.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.15%)
# 	-0.1491	 = Validation score   (-root_mean_squared_error)
# 	22.51s	 = Training   runtime
# 	3.51s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 15181.39s of the 24122.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	-0.1533	 = Validation score   (-root_mean_squared_error)
# 	428.81s	 = Training   runtime
# 	0.79s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 14748.02s of the 23688.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.12%)
# 	-0.1487	 = Validation score   (-root_mean_squared_error)
# 	60.54s	 = Training   runtime
# 	10.48s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 14682.72s of the 23623.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	-0.1484	 = Validation score   (-root_mean_squared_error)
# 	253.23s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 14425.78s of the 23366.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	-0.1527	 = Validation score   (-root_mean_squared_error)
# 	563.58s	 = Training   runtime
# 	0.85s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 13858.03s of the 22798.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	-0.1482	 = Validation score   (-root_mean_squared_error)
# 	292.83s	 = Training   runtime
# 	186.69s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 13553.48s of the 22494.1s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.18%)
# 	-0.1524	 = Validation score   (-root_mean_squared_error)
# 	1074.33s	 = Training   runtime
# 	4.62s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 12474.64s of the 21415.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.17%)
# 	-0.1482	 = Validation score   (-root_mean_squared_error)
# 	365.3s	 = Training   runtime
# 	4.31s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 12104.35s of the 21044.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	-0.1503	 = Validation score   (-root_mean_squared_error)
# 	792.48s	 = Training   runtime
# 	741.16s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 11292.04s of the 20232.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	-0.1527	 = Validation score   (-root_mean_squared_error)
# 	658.21s	 = Training   runtime
# 	1.51s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 10629.79s of the 19570.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.22%)
# 	-0.1488	 = Validation score   (-root_mean_squared_error)
# 	69.54s	 = Training   runtime
# 	29.26s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 10554.0s of the 19494.62s of remaining time.
# 	-0.1508	 = Validation score   (-root_mean_squared_error)
# 	16.23s	 = Training   runtime
# 	4.61s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 10530.26s of the 19470.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	-0.1483	 = Validation score   (-root_mean_squared_error)
# 	742.11s	 = Training   runtime
# 	0.69s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 9784.29s of the 18724.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.18%)
# 	-0.151	 = Validation score   (-root_mean_squared_error)
# 	135.25s	 = Training   runtime
# 	1.13s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 9644.85s of the 18585.47s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.15%)
# 	-0.1483	 = Validation score   (-root_mean_squared_error)
# 	1092.3s	 = Training   runtime
# 	1.57s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 8547.25s of the 17487.86s of remaining time.
# 	-0.1517	 = Validation score   (-root_mean_squared_error)
# 	57.39s	 = Training   runtime
# 	6.51s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 8476.92s of the 17417.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	-0.1496	 = Validation score   (-root_mean_squared_error)
# 	1015.93s	 = Training   runtime
# 	1052.87s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 7352.57s of the 16293.18s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.19%)
# 	-0.1519	 = Validation score   (-root_mean_squared_error)
# 	921.27s	 = Training   runtime
# 	5.71s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 6426.35s of the 15366.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.16%)
# 	-0.1487	 = Validation score   (-root_mean_squared_error)
# 	35.11s	 = Training   runtime
# 	6.24s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 6386.64s of the 15327.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	-0.1537	 = Validation score   (-root_mean_squared_error)
# 	781.74s	 = Training   runtime
# 	1.67s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 5600.79s of the 14541.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.12%)
# 	-0.148	 = Validation score   (-root_mean_squared_error)
# 	64.78s	 = Training   runtime
# 	18.17s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 5529.98s of the 14470.6s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	-0.1537	 = Validation score   (-root_mean_squared_error)
# 	1419.97s	 = Training   runtime
# 	10.24s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 4104.85s of the 13045.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	-0.1484	 = Validation score   (-root_mean_squared_error)
# 	390.22s	 = Training   runtime
# 	2.73s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 3710.38s of the 12651.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.19%)
# 	-0.1558	 = Validation score   (-root_mean_squared_error)
# 	1054.69s	 = Training   runtime
# 	6.79s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 2650.85s of the 11591.47s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.19%)
# 	-0.149	 = Validation score   (-root_mean_squared_error)
# 	21.87s	 = Training   runtime
# 	1.6s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 2624.31s of the 11564.93s of remaining time.
# 	-0.1502	 = Validation score   (-root_mean_squared_error)
# 	14.1s	 = Training   runtime
# 	4.39s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 2604.72s of the 11545.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	-0.1483	 = Validation score   (-root_mean_squared_error)
# 	1087.77s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 1512.51s of the 10453.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.19%)
# 	-0.1546	 = Validation score   (-root_mean_squared_error)
# 	505.27s	 = Training   runtime
# 	3.21s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 1002.78s of the 9943.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	-0.1526	 = Validation score   (-root_mean_squared_error)
# 	258.75s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: LightGBM_r161_BAG_L1 ... Training model for up to 739.75s of the 9680.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.15%)
# 	-0.1482	 = Validation score   (-root_mean_squared_error)
# 	173.02s	 = Training   runtime
# 	103.85s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 554.78s of the 9495.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.19%)
# 	-0.1535	 = Validation score   (-root_mean_squared_error)
# 	231.79s	 = Training   runtime
# 	1.43s	 = Validation runtime
# Fitting model: CatBoost_r70_BAG_L1 ... Training model for up to 318.95s of the 9259.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.12%)
# 	-0.1484	 = Validation score   (-root_mean_squared_error)
# 	261.58s	 = Training   runtime
# 	4.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r156_BAG_L1 ... Training model for up to 53.05s of the 8993.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.19%)
# 	-0.1542	 = Validation score   (-root_mean_squared_error)
# 	62.07s	 = Training   runtime
# 	2.15s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 1786.79s of the 8926.17s of remaining time.
# 	Ensemble Weights: {'LightGBM_r130_BAG_L1': 0.412, 'RandomForestMSE_BAG_L1': 0.118, 'CatBoost_BAG_L1': 0.118, 'CatBoost_r9_BAG_L1': 0.118, 'CatBoost_r137_BAG_L1': 0.118, 'NeuralNetFastAI_BAG_L1': 0.059, 'CatBoost_r69_BAG_L1': 0.059}
# 	-0.1474	 = Validation score   (-root_mean_squared_error)
# 	0.51s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 8925.61s of the 8925.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.45%)
# 	-0.1474	 = Validation score   (-root_mean_squared_error)
# 	137.32s	 = Training   runtime
# 	11.48s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 8783.36s of the 8782.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.44%)
# 	-0.1475	 = Validation score   (-root_mean_squared_error)
# 	80.51s	 = Training   runtime
# 	2.7s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 8698.38s of the 8697.98s of remaining time.
# 	-0.1488	 = Validation score   (-root_mean_squared_error)
# 	1098.39s	 = Training   runtime
# 	8.05s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 7589.6s of the 7589.2s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.47%)
# 	-0.1475	 = Validation score   (-root_mean_squared_error)
# 	176.25s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 7409.11s of the 7408.71s of remaining time.
# 	-0.1484	 = Validation score   (-root_mean_squared_error)
# 	120.49s	 = Training   runtime
# 	7.58s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 7279.78s of the 7279.39s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.72%)
# 	-0.1472	 = Validation score   (-root_mean_squared_error)
# 	443.83s	 = Training   runtime
# 	3.22s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 6831.24s of the 6830.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.61%)
# 	-0.1476	 = Validation score   (-root_mean_squared_error)
# 	26.79s	 = Training   runtime
# 	2.14s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 6799.54s of the 6799.15s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.40%)
# 	-0.1487	 = Validation score   (-root_mean_squared_error)
# 	267.31s	 = Training   runtime
# 	1.02s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 6527.29s of the 6526.9s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	-0.1477	 = Validation score   (-root_mean_squared_error)
# 	141.24s	 = Training   runtime
# 	6.57s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 6381.17s of the 6380.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.48%)
# 	-0.1475	 = Validation score   (-root_mean_squared_error)
# 	81.23s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 6295.08s of the 6294.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.40%)
# 	-0.1485	 = Validation score   (-root_mean_squared_error)
# 	433.61s	 = Training   runtime
# 	1.16s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L2 ... Training model for up to 5857.17s of the 5856.78s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.47%)
# 	-0.1474	 = Validation score   (-root_mean_squared_error)
# 	240.36s	 = Training   runtime
# 	17.38s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L2 ... Training model for up to 5610.4s of the 5610.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.72%)
# 	-0.1472	 = Validation score   (-root_mean_squared_error)
# 	1420.24s	 = Training   runtime
# 	5.28s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L2 ... Training model for up to 4184.74s of the 4184.33s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.82%)
# 	-0.1473	 = Validation score   (-root_mean_squared_error)
# 	258.61s	 = Training   runtime
# 	0.98s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L2 ... Training model for up to 3921.2s of the 3920.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	-0.1473	 = Validation score   (-root_mean_squared_error)
# 	451.19s	 = Training   runtime
# 	85.7s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L2 ... Training model for up to 3463.18s of the 3462.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.40%)
# 	-0.1481	 = Validation score   (-root_mean_squared_error)
# 	649.73s	 = Training   runtime
# 	1.8s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L2 ... Training model for up to 2809.07s of the 2808.68s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=1.06%)
# 	-0.1479	 = Validation score   (-root_mean_squared_error)
# 	154.46s	 = Training   runtime
# 	10.88s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L2 ... Training model for up to 2649.41s of the 2649.02s of remaining time.
# 	-0.1484	 = Validation score   (-root_mean_squared_error)
# 	95.55s	 = Training   runtime
# 	7.89s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L2 ... Training model for up to 2542.89s of the 2542.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.43%)
# 	-0.1475	 = Validation score   (-root_mean_squared_error)
# 	89.6s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L2 ... Training model for up to 2449.21s of the 2448.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.72%)
# 	-0.1472	 = Validation score   (-root_mean_squared_error)
# 	154.04s	 = Training   runtime
# 	1.46s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L2 ... Training model for up to 2290.98s of the 2290.57s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.67%)
# 	-0.1474	 = Validation score   (-root_mean_squared_error)
# 	524.16s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L2 ... Training model for up to 1762.2s of the 1761.81s of remaining time.
# 	-0.1488	 = Validation score   (-root_mean_squared_error)
# 	830.2s	 = Training   runtime
# 	9.2s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L2 ... Training model for up to 919.32s of the 918.94s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.54%)
# 	-0.1474	 = Validation score   (-root_mean_squared_error)
# 	158.22s	 = Training   runtime
# 	23.74s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L2 ... Training model for up to 753.06s of the 752.66s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.73%)
# 	-0.1475	 = Validation score   (-root_mean_squared_error)
# 	615.64s	 = Training   runtime
# 	5.56s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L2 ... Training model for up to 132.41s of the 132.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.62%)
# 	-0.1476	 = Validation score   (-root_mean_squared_error)
# 	26.7s	 = Training   runtime
# 	2.28s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L2 ... Training model for up to 101.02s of the 100.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.40%)
# 	-0.1502	 = Validation score   (-root_mean_squared_error)
# 	84.28s	 = Training   runtime
# 	1.86s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L2 ... Training model for up to 12.28s of the 11.79s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=0.50%)
# 	-0.2724	 = Validation score   (-root_mean_squared_error)
# 	19.41s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 892.56s of the -15.63s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_r102_BAG_L2': 0.32, 'NeuralNetFastAI_r191_BAG_L2': 0.24, 'LightGBM_r188_BAG_L2': 0.16, 'LightGBM_r131_BAG_L2': 0.08, 'XGBoost_r33_BAG_L2': 0.08, 'RandomForest_r195_BAG_L2': 0.08, 'NeuralNetFastAI_BAG_L2': 0.04}
# 	-0.1471	 = Validation score   (-root_mean_squared_error)
# 	0.36s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 26825.06s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/models")

# %%
# %%time
predictor.leaderboard(train)
# Out:
# INFO:sklearnex: sklearn.neighbors.KNeighborsRegressor.predict: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsRegressor.predict: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# CPU times: user 1h 27min 10s, sys: 34.8 s, total: 1h 27min 45s
# Wall time: 44min 11s
#                           model  score_test  score_val  \
# 0         KNeighborsDist_BAG_L1   -0.008900  -0.163956
# 1      RandomForest_r195_BAG_L1   -0.055975  -0.151740
# 2        RandomForestMSE_BAG_L1   -0.069901  -0.151892
# 3         ExtraTrees_r42_BAG_L1   -0.080895  -0.150771
# 4          ExtraTreesMSE_BAG_L1   -0.084212  -0.150675
# ..                          ...         ...        ...
# 65  NeuralNetFastAI_r103_BAG_L1   -0.152755  -0.154633
# 66  NeuralNetFastAI_r143_BAG_L1   -0.152931  -0.153539
# 67  NeuralNetFastAI_r156_BAG_L1   -0.153394  -0.154230
# 68   NeuralNetFastAI_r11_BAG_L1   -0.153439  -0.155755
# 69         LightGBM_r130_BAG_L2   -0.271810  -0.272417
#
#                 eval_metric  pred_time_test  pred_time_val      fit_time  \
# 0   root_mean_squared_error        0.857852       0.813467      0.123846
# 1   root_mean_squared_error       23.866434       6.505976     57.385278
# 2   root_mean_squared_error        6.760302       4.836047     62.088589
# 3   root_mean_squared_error        8.984286       4.607958     16.226547
# 4   root_mean_squared_error        6.692741       4.411572     17.638795
# ..                      ...             ...            ...           ...
# 65  root_mean_squared_error       14.845546       3.211777    505.271704
# 66  root_mean_squared_error        5.764209       1.434450    231.788147
# 67  root_mean_squared_error        3.382385       2.148957     62.065611
# 68  root_mean_squared_error       30.420574       6.791892   1054.694964
# 69  root_mean_squared_error     2298.954424    2977.641410  17533.027378
#
#     pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  \
# 0                  0.857852                0.813467           0.123846
# 1                 23.866434                6.505976          57.385278
# 2                  6.760302                4.836047          62.088589
# 3                  8.984286                4.607958          16.226547
# 4                  6.692741                4.411572          17.638795
# ..                      ...                     ...                ...
# 65                14.845546                3.211777         505.271704
# 66                 5.764209                1.434450         231.788147
# 67                 3.382385                2.148957          62.065611
# 68                30.420574                6.791892        1054.694964
# 69                 0.429299                0.425506          19.409090
#
#     stack_level  can_infer  fit_order
# 0             1       True          2
# 1             1       True         24
# 2             1       True          5
# 3             1       True         20
# 4             1       True          7
# ..          ...        ...        ...
# 65            1       True         36
# 66            1       True         39
# 67            1       True         41
# 68            1       True         32
# 69            2       True         69
#
# [70 rows x 13 columns]

# %%
preds = predictor.predict(test)
# Out:
# INFO:sklearnex: sklearn.neighbors.KNeighborsRegressor.predict: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU
# INFO:sklearnex: sklearn.neighbors.KNeighborsRegressor.predict: running accelerated version on CPU
# INFO:sklearnex: sklearn.utils.validation._assert_all_finite: running accelerated version on CPU

# %%
def create_submission_files(preds, config, notebook='04'):
    sub = sample_sub.copy()
    # inverse transform for log-transformed target and clipping range based on train data
    sub[TARGET] = np.expm1(preds).clip(1, 29)
    sub.to_csv(f'nb{notebook}_{config}.csv', index=False)

# %%
config = f'autogluon_rmse_{time_limit // 3600}hr'
create_submission_files(preds, config)
