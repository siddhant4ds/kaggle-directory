# %%
import time
import gc
gc.enable()

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

import featuretools as ft

from itertools import combinations
from sklearn.metrics import r2_score
from sklearn.base import clone
from sklearn.model_selection import StratifiedKFold
import xgboost as xgb 

SEED = 2024

# %%
# Check GPU availability
import subprocess

try:
    subprocess.check_output('nvidia-smi')
    DEVICE = 'cuda'
except Exception:
    DEVICE = 'cpu'

print(f'Available device: {DEVICE}')
# Out:
# Available device: cuda

# %%
DATA_DIR = '/kaggle/input/playground-series-s4e5'

train = pd.read_csv(f'{DATA_DIR}/train.csv')
test = pd.read_csv(f'{DATA_DIR}/test.csv')

# %%
def reduce_memory_usage(df):
    start_memory = df.memory_usage().sum() / 1024**2
    print(f"Memory usage of dataframe is {start_memory} MB")
    for col in df.columns:
        col_type = df[col].dtype
        if col_type != 'object':
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    pass
        else:
            df[col] = df[col].astype('category')
    end_memory = df.memory_usage().sum() / 1024**2
    print(f"Memory usage of dataframe after reduction {end_memory} MB")
    print(f"Reduced by {100 * (start_memory - end_memory) / start_memory} % ")
    return df

# %%
train = reduce_memory_usage(train)
test = reduce_memory_usage(test)
# Out:
# Memory usage of dataframe is 187.64549255371094 MB
# Memory usage of dataframe after reduction 27.720460891723633 MB
# Reduced by 85.22721728378899 %
# Memory usage of dataframe is 119.4108657836914 MB
# Memory usage of dataframe after reduction 17.058799743652344 MB
# Reduced by 85.71419809102318 %

# %%
TARGET = 'FloodProbability'
og_features = list(test.columns)

# %%
labels = train.pop(TARGET)
composite = pd.concat([train, test], axis=0)

# %%
es = ft.EntitySet(id='data')

es = es.add_dataframe(
      dataframe_name='composite',
      dataframe=composite,
      index='id')

feature_matrix, feature_defs = ft.dfs(
    entityset=es, 
    target_dataframe_name='composite',
    agg_primitives=['sum', 'std'],
    trans_primitives=['add_numeric'])

# %%
feature_matrix.head()
# Out:
#     MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# id
# 0                  5                   8                5              8
# 1                  6                   7                4              4
# 2                  6                   5                6              7
# 3                  3                   4                6              5
# 4                  5                   3                2              6
#
#     Urbanization  ClimateChange  DamsQuality  Siltation  \
# id
# 0              6              4            4          3
# 1              8              8            3          5
# 2              3              7            1          5
# 3              4              8            4          7
# 4              4              4            3          3
#
#     AgriculturalPractices  Encroachments  IneffectiveDisasterPreparedness  \
# id
# 0                       3              4                                2
# 1                       4              6                                9
# 2                       4              5                                6
# 3                       6              8                                5
# 4                       3              3                                5
#
#     DrainageSystems  CoastalVulnerability  Landslides  Watersheds  \
# id
# 0                 5                     3           3           5
# 1                 7                     2           0           3
# 2                 7                     3           7           5
# 3                 2                     4           7           4
# 4                 2                     2           6           6
#
#     DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# id
# 0                             4                7            5
# 1                             5                3            3
# 2                             6                8            2
# 3                             4                6            5
# 4                             4                1            2
#
#     InadequatePlanning  PoliticalFactors  \
# id
# 0                    7                 3
# 1                    4                 3
# 2                    3                 3
# 3                    7                 5
# 4                    3                 5
#
#     AgriculturalPractices + ClimateChange  \
# id
# 0                                     7.0
# 1                                    12.0
# 2                                    11.0
# 3                                    14.0
# 4                                     7.0
#
#     AgriculturalPractices + CoastalVulnerability  \
# id
# 0                                            6.0
# 1                                            6.0
# 2                                            7.0
# 3                                           10.0
# 4                                            5.0
#
#     AgriculturalPractices + DamsQuality  \
# id
# 0                                   7.0
# 1                                   7.0
# 2                                   5.0
# 3                                  10.0
# 4                                   6.0
#
#     AgriculturalPractices + Deforestation  \
# id
# 0                                    11.0
# 1                                     8.0
# 2                                    11.0
# 3                                    11.0
# 4                                     9.0
#
#     AgriculturalPractices + DeterioratingInfrastructure  \
# id
# 0                                                 7.0
# 1                                                 9.0
# 2                                                10.0
# 3                                                10.0
# 4                                                 7.0
#
#     AgriculturalPractices + DrainageSystems  \
# id
# 0                                       8.0
# 1                                      11.0
# 2                                      11.0
# 3                                       8.0
# 4                                       5.0
#
#     AgriculturalPractices + Encroachments  \
# id
# 0                                     7.0
# 1                                    10.0
# 2                                     9.0
# 3                                    14.0
# 4                                     6.0
#
#     AgriculturalPractices + InadequatePlanning  \
# id
# 0                                         10.0
# 1                                          8.0
# 2                                          7.0
# 3                                         13.0
# 4                                          6.0
#
#     AgriculturalPractices + IneffectiveDisasterPreparedness  \
# id
# 0                                                 5.0
# 1                                                13.0
# 2                                                10.0
# 3                                                11.0
# 4                                                 8.0
#
#     AgriculturalPractices + Landslides  \
# id
# 0                                  6.0
# 1                                  4.0
# 2                                 11.0
# 3                                 13.0
# 4                                  9.0
#
#     AgriculturalPractices + MonsoonIntensity  \
# id
# 0                                        8.0
# 1                                       10.0
# 2                                       10.0
# 3                                        9.0
# 4                                        8.0
#
#     AgriculturalPractices + PoliticalFactors  \
# id
# 0                                        6.0
# 1                                        7.0
# 2                                        7.0
# 3                                       11.0
# 4                                        8.0
#
#     AgriculturalPractices + PopulationScore  \
# id
# 0                                      10.0
# 1                                       7.0
# 2                                      12.0
# 3                                      12.0
# 4                                       4.0
#
#     AgriculturalPractices + RiverManagement  \
# id
# 0                                       8.0
# 1                                       8.0
# 2                                      10.0
# 3                                      12.0
# 4                                       5.0
#
#     AgriculturalPractices + Siltation  \
# id
# 0                                 6.0
# 1                                 9.0
# 2                                 9.0
# 3                                13.0
# 4                                 6.0
#
#     AgriculturalPractices + TopographyDrainage  \
# id
# 0                                         11.0
# 1                                         11.0
# 2                                          9.0
# 3                                         10.0
# 4                                          6.0
#
#     AgriculturalPractices + Urbanization  AgriculturalPractices + Watersheds  \
# id
# 0                                    9.0                                 8.0
# 1                                   12.0                                 7.0
# 2                                    7.0                                 9.0
# 3                                   10.0                                10.0
# 4                                    7.0                                 9.0
#
#     AgriculturalPractices + WetlandLoss  ClimateChange + CoastalVulnerability  \
# id
# 0                                   8.0                                   7.0
# 1                                   7.0                                  10.0
# 2                                   6.0                                  10.0
# 3                                  11.0                                  12.0
# 4                                   5.0                                   6.0
#
#     ClimateChange + DamsQuality  ClimateChange + Deforestation  \
# id
# 0                           8.0                           12.0
# 1                          11.0                           12.0
# 2                           8.0                           14.0
# 3                          12.0                           13.0
# 4                           7.0                           10.0
#
#     ClimateChange + DeterioratingInfrastructure  \
# id
# 0                                           8.0
# 1                                          13.0
# 2                                          13.0
# 3                                          12.0
# 4                                           8.0
#
#     ClimateChange + DrainageSystems  ClimateChange + Encroachments  \
# id
# 0                               9.0                            8.0
# 1                              15.0                           14.0
# 2                              14.0                           12.0
# 3                              10.0                           16.0
# 4                               6.0                            7.0
#
#     ClimateChange + InadequatePlanning  \
# id
# 0                                 11.0
# 1                                 12.0
# 2                                 10.0
# 3                                 15.0
# 4                                  7.0
#
#     ClimateChange + IneffectiveDisasterPreparedness  \
# id
# 0                                               6.0
# 1                                              17.0
# 2                                              13.0
# 3                                              13.0
# 4                                               9.0
#
#     ClimateChange + Landslides  ClimateChange + MonsoonIntensity  \
# id
# 0                          7.0                               9.0
# 1                          8.0                              14.0
# 2                         14.0                              13.0
# 3                         15.0                              11.0
# 4                         10.0                               9.0
#
#     ClimateChange + PoliticalFactors  ClimateChange + PopulationScore  \
# id
# 0                                7.0                             11.0
# 1                               11.0                             11.0
# 2                               10.0                             15.0
# 3                               13.0                             14.0
# 4                                9.0                              5.0
#
#     ClimateChange + RiverManagement  ClimateChange + Siltation  \
# id
# 0                               9.0                        7.0
# 1                              12.0                       13.0
# 2                              13.0                       12.0
# 3                              14.0                       15.0
# 4                               6.0                        7.0
#
#     ClimateChange + TopographyDrainage  ClimateChange + Urbanization  \
# id
# 0                                 12.0                          10.0
# 1                                 15.0                          16.0
# 2                                 12.0                          10.0
# 3                                 12.0                          12.0
# 4                                  7.0                           8.0
#
#     ClimateChange + Watersheds  ClimateChange + WetlandLoss  \
# id
# 0                          9.0                          9.0
# 1                         11.0                         11.0
# 2                         12.0                          9.0
# 3                         12.0                         13.0
# 4                         10.0                          6.0
#
#     CoastalVulnerability + DamsQuality  CoastalVulnerability + Deforestation  \
# id
# 0                                  7.0                                  11.0
# 1                                  5.0                                   6.0
# 2                                  4.0                                  10.0
# 3                                  8.0                                   9.0
# 4                                  5.0                                   8.0
#
#     CoastalVulnerability + DeterioratingInfrastructure  \
# id
# 0                                                 7.0
# 1                                                 7.0
# 2                                                 9.0
# 3                                                 8.0
# 4                                                 6.0
#
#     CoastalVulnerability + DrainageSystems  \
# id
# 0                                      8.0
# 1                                      9.0
# 2                                     10.0
# 3                                      6.0
# 4                                      4.0
#
#     CoastalVulnerability + Encroachments  \
# id
# 0                                    7.0
# 1                                    8.0
# 2                                    8.0
# 3                                   12.0
# 4                                    5.0
#
#     CoastalVulnerability + InadequatePlanning  \
# id
# 0                                        10.0
# 1                                         6.0
# 2                                         6.0
# 3                                        11.0
# 4                                         5.0
#
#     CoastalVulnerability + IneffectiveDisasterPreparedness  \
# id
# 0                                                 5.0
# 1                                                11.0
# 2                                                 9.0
# 3                                                 9.0
# 4                                                 7.0
#
#     CoastalVulnerability + Landslides  \
# id
# 0                                 6.0
# 1                                 2.0
# 2                                10.0
# 3                                11.0
# 4                                 8.0
#
#     CoastalVulnerability + MonsoonIntensity  \
# id
# 0                                       8.0
# 1                                       8.0
# 2                                       9.0
# 3                                       7.0
# 4                                       7.0
#
#     CoastalVulnerability + PoliticalFactors  \
# id
# 0                                       6.0
# 1                                       5.0
# 2                                       6.0
# 3                                       9.0
# 4                                       7.0
#
#     CoastalVulnerability + PopulationScore  \
# id
# 0                                     10.0
# 1                                      5.0
# 2                                     11.0
# 3                                     10.0
# 4                                      3.0
#
#     CoastalVulnerability + RiverManagement  CoastalVulnerability + Siltation  \
# id
# 0                                      8.0                               6.0
# 1                                      6.0                               7.0
# 2                                      9.0                               8.0
# 3                                     10.0                              11.0
# 4                                      4.0                               5.0
#
#     CoastalVulnerability + TopographyDrainage  \
# id
# 0                                        11.0
# 1                                         9.0
# 2                                         8.0
# 3                                         8.0
# 4                                         5.0
#
#     CoastalVulnerability + Urbanization  CoastalVulnerability + Watersheds  \
# id
# 0                                   9.0                                8.0
# 1                                  10.0                                5.0
# 2                                   6.0                                8.0
# 3                                   8.0                                8.0
# 4                                   6.0                                8.0
#
#     CoastalVulnerability + WetlandLoss  DamsQuality + Deforestation  \
# id
# 0                                  8.0                         12.0
# 1                                  5.0                          7.0
# 2                                  5.0                          8.0
# 3                                  9.0                          9.0
# 4                                  4.0                          9.0
#
#     DamsQuality + DeterioratingInfrastructure  DamsQuality + DrainageSystems  \
# id
# 0                                         8.0                            9.0
# 1                                         8.0                           10.0
# 2                                         7.0                            8.0
# 3                                         8.0                            6.0
# 4                                         7.0                            5.0
#
#     DamsQuality + Encroachments  DamsQuality + InadequatePlanning  \
# id
# 0                           8.0                              11.0
# 1                           9.0                               7.0
# 2                           6.0                               4.0
# 3                          12.0                              11.0
# 4                           6.0                               6.0
#
#     DamsQuality + IneffectiveDisasterPreparedness  DamsQuality + Landslides  \
# id
# 0                                             6.0                       7.0
# 1                                            12.0                       3.0
# 2                                             7.0                       8.0
# 3                                             9.0                      11.0
# 4                                             8.0                       9.0
#
#     DamsQuality + MonsoonIntensity  DamsQuality + PoliticalFactors  \
# id
# 0                              9.0                             7.0
# 1                              9.0                             6.0
# 2                              7.0                             4.0
# 3                              7.0                             9.0
# 4                              8.0                             8.0
#
#     DamsQuality + PopulationScore  DamsQuality + RiverManagement  \
# id
# 0                            11.0                            9.0
# 1                             6.0                            7.0
# 2                             9.0                            7.0
# 3                            10.0                           10.0
# 4                             4.0                            5.0
#
#     DamsQuality + Siltation  DamsQuality + TopographyDrainage  \
# id
# 0                       7.0                              12.0
# 1                       8.0                              10.0
# 2                       6.0                               6.0
# 3                      11.0                               8.0
# 4                       6.0                               6.0
#
#     DamsQuality + Urbanization  DamsQuality + Watersheds  \
# id
# 0                         10.0                       9.0
# 1                         11.0                       6.0
# 2                          4.0                       6.0
# 3                          8.0                       8.0
# 4                          7.0                       9.0
#
#     DamsQuality + WetlandLoss  Deforestation + DeterioratingInfrastructure  \
# id
# 0                         9.0                                         12.0
# 1                         6.0                                          9.0
# 2                         3.0                                         13.0
# 3                         9.0                                          9.0
# 4                         5.0                                         10.0
#
#     Deforestation + DrainageSystems  Deforestation + Encroachments  \
# id
# 0                              13.0                           12.0
# 1                              11.0                           10.0
# 2                              14.0                           12.0
# 3                               7.0                           13.0
# 4                               8.0                            9.0
#
#     Deforestation + InadequatePlanning  \
# id
# 0                                 15.0
# 1                                  8.0
# 2                                 10.0
# 3                                 12.0
# 4                                  9.0
#
#     Deforestation + IneffectiveDisasterPreparedness  \
# id
# 0                                              10.0
# 1                                              13.0
# 2                                              13.0
# 3                                              10.0
# 4                                              11.0
#
#     Deforestation + Landslides  Deforestation + MonsoonIntensity  \
# id
# 0                         11.0                              13.0
# 1                          4.0                              10.0
# 2                         14.0                              13.0
# 3                         12.0                               8.0
# 4                         12.0                              11.0
#
#     Deforestation + PoliticalFactors  Deforestation + PopulationScore  \
# id
# 0                               11.0                             15.0
# 1                                7.0                              7.0
# 2                               10.0                             15.0
# 3                               10.0                             11.0
# 4                               11.0                              7.0
#
#     Deforestation + RiverManagement  Deforestation + Siltation  \
# id
# 0                              13.0                       11.0
# 1                               8.0                        9.0
# 2                              13.0                       12.0
# 3                              11.0                       12.0
# 4                               8.0                        9.0
#
#     Deforestation + TopographyDrainage  Deforestation + Urbanization  \
# id
# 0                                 16.0                          14.0
# 1                                 11.0                          12.0
# 2                                 12.0                          10.0
# 3                                  9.0                           9.0
# 4                                  9.0                          10.0
#
#     Deforestation + Watersheds  Deforestation + WetlandLoss  \
# id
# 0                         13.0                         13.0
# 1                          7.0                          7.0
# 2                         12.0                          9.0
# 3                          9.0                         10.0
# 4                         12.0                          8.0
#
#     DeterioratingInfrastructure + DrainageSystems  \
# id
# 0                                             9.0
# 1                                            12.0
# 2                                            13.0
# 3                                             6.0
# 4                                             6.0
#
#     DeterioratingInfrastructure + Encroachments  \
# id
# 0                                           8.0
# 1                                          11.0
# 2                                          11.0
# 3                                          12.0
# 4                                           7.0
#
#     DeterioratingInfrastructure + InadequatePlanning  \
# id
# 0                                               11.0
# 1                                                9.0
# 2                                                9.0
# 3                                               11.0
# 4                                                7.0
#
#     DeterioratingInfrastructure + IneffectiveDisasterPreparedness  \
# id
# 0                                                 6.0
# 1                                                14.0
# 2                                                12.0
# 3                                                 9.0
# 4                                                 9.0
#
#     DeterioratingInfrastructure + Landslides  \
# id
# 0                                        7.0
# 1                                        5.0
# 2                                       13.0
# 3                                       11.0
# 4                                       10.0
#
#     DeterioratingInfrastructure + MonsoonIntensity  \
# id
# 0                                              9.0
# 1                                             11.0
# 2                                             12.0
# 3                                              7.0
# 4                                              9.0
#
#     DeterioratingInfrastructure + PoliticalFactors  \
# id
# 0                                              7.0
# 1                                              8.0
# 2                                              9.0
# 3                                              9.0
# 4                                              9.0
#
#     DeterioratingInfrastructure + PopulationScore  \
# id
# 0                                            11.0
# 1                                             8.0
# 2                                            14.0
# 3                                            10.0
# 4                                             5.0
#
#     DeterioratingInfrastructure + RiverManagement  \
# id
# 0                                             9.0
# 1                                             9.0
# 2                                            12.0
# 3                                            10.0
# 4                                             6.0
#
#     DeterioratingInfrastructure + Siltation  \
# id
# 0                                       7.0
# 1                                      10.0
# 2                                      11.0
# 3                                      11.0
# 4                                       7.0
#
#     DeterioratingInfrastructure + TopographyDrainage  \
# id
# 0                                               12.0
# 1                                               12.0
# 2                                               11.0
# 3                                                8.0
# 4                                                7.0
#
#     DeterioratingInfrastructure + Urbanization  \
# id
# 0                                         10.0
# 1                                         13.0
# 2                                          9.0
# 3                                          8.0
# 4                                          8.0
#
#     DeterioratingInfrastructure + Watersheds  \
# id
# 0                                        9.0
# 1                                        8.0
# 2                                       11.0
# 3                                        8.0
# 4                                       10.0
#
#     DeterioratingInfrastructure + WetlandLoss  \
# id
# 0                                         9.0
# 1                                         8.0
# 2                                         8.0
# 3                                         9.0
# 4                                         6.0
#
#     DrainageSystems + Encroachments  DrainageSystems + InadequatePlanning  \
# id
# 0                               9.0                                  12.0
# 1                              13.0                                  11.0
# 2                              12.0                                  10.0
# 3                              10.0                                   9.0
# 4                               5.0                                   5.0
#
#     DrainageSystems + IneffectiveDisasterPreparedness  \
# id
# 0                                                 7.0
# 1                                                16.0
# 2                                                13.0
# 3                                                 7.0
# 4                                                 7.0
#
#     DrainageSystems + Landslides  DrainageSystems + MonsoonIntensity  \
# id
# 0                            8.0                                10.0
# 1                            7.0                                13.0
# 2                           14.0                                13.0
# 3                            9.0                                 5.0
# 4                            8.0                                 7.0
#
#     DrainageSystems + PoliticalFactors  DrainageSystems + PopulationScore  \
# id
# 0                                  8.0                               12.0
# 1                                 10.0                               10.0
# 2                                 10.0                               15.0
# 3                                  7.0                                8.0
# 4                                  7.0                                3.0
#
#     DrainageSystems + RiverManagement  DrainageSystems + Siltation  \
# id
# 0                                10.0                          8.0
# 1                                11.0                         12.0
# 2                                13.0                         12.0
# 3                                 8.0                          9.0
# 4                                 4.0                          5.0
#
#     DrainageSystems + TopographyDrainage  DrainageSystems + Urbanization  \
# id
# 0                                   13.0                            11.0
# 1                                   14.0                            15.0
# 2                                   12.0                            10.0
# 3                                    6.0                             6.0
# 4                                    5.0                             6.0
#
#     DrainageSystems + Watersheds  DrainageSystems + WetlandLoss  \
# id
# 0                           10.0                           10.0
# 1                           10.0                           10.0
# 2                           12.0                            9.0
# 3                            6.0                            7.0
# 4                            8.0                            4.0
#
#     Encroachments + InadequatePlanning  \
# id
# 0                                 11.0
# 1                                 10.0
# 2                                  8.0
# 3                                 15.0
# 4                                  6.0
#
#     Encroachments + IneffectiveDisasterPreparedness  \
# id
# 0                                               6.0
# 1                                              15.0
# 2                                              11.0
# 3                                              13.0
# 4                                               8.0
#
#     Encroachments + Landslides  Encroachments + MonsoonIntensity  \
# id
# 0                          7.0                               9.0
# 1                          6.0                              12.0
# 2                         12.0                              11.0
# 3                         15.0                              11.0
# 4                          9.0                               8.0
#
#     Encroachments + PoliticalFactors  Encroachments + PopulationScore  \
# id
# 0                                7.0                             11.0
# 1                                9.0                              9.0
# 2                                8.0                             13.0
# 3                               13.0                             14.0
# 4                                8.0                              4.0
#
#     Encroachments + RiverManagement  Encroachments + Siltation  \
# id
# 0                               9.0                        7.0
# 1                              10.0                       11.0
# 2                              11.0                       10.0
# 3                              14.0                       15.0
# 4                               5.0                        6.0
#
#     Encroachments + TopographyDrainage  Encroachments + Urbanization  \
# id
# 0                                 12.0                          10.0
# 1                                 13.0                          14.0
# 2                                 10.0                           8.0
# 3                                 12.0                          12.0
# 4                                  6.0                           7.0
#
#     Encroachments + Watersheds  Encroachments + WetlandLoss  \
# id
# 0                          9.0                          9.0
# 1                          9.0                          9.0
# 2                         10.0                          7.0
# 3                         12.0                         13.0
# 4                          9.0                          5.0
#
#     InadequatePlanning + IneffectiveDisasterPreparedness  \
# id
# 0                                                 9.0
# 1                                                13.0
# 2                                                 9.0
# 3                                                12.0
# 4                                                 8.0
#
#     InadequatePlanning + Landslides  InadequatePlanning + MonsoonIntensity  \
# id
# 0                              10.0                                   12.0
# 1                               4.0                                   10.0
# 2                              10.0                                    9.0
# 3                              14.0                                   10.0
# 4                               9.0                                    8.0
#
#     InadequatePlanning + PoliticalFactors  \
# id
# 0                                    10.0
# 1                                     7.0
# 2                                     6.0
# 3                                    12.0
# 4                                     8.0
#
#     InadequatePlanning + PopulationScore  \
# id
# 0                                   14.0
# 1                                    7.0
# 2                                   11.0
# 3                                   13.0
# 4                                    4.0
#
#     InadequatePlanning + RiverManagement  InadequatePlanning + Siltation  \
# id
# 0                                   12.0                            10.0
# 1                                    8.0                             9.0
# 2                                    9.0                             8.0
# 3                                   13.0                            14.0
# 4                                    5.0                             6.0
#
#     InadequatePlanning + TopographyDrainage  \
# id
# 0                                      15.0
# 1                                      11.0
# 2                                       8.0
# 3                                      11.0
# 4                                       6.0
#
#     InadequatePlanning + Urbanization  InadequatePlanning + Watersheds  \
# id
# 0                                13.0                             12.0
# 1                                12.0                              7.0
# 2                                 6.0                              8.0
# 3                                11.0                             11.0
# 4                                 7.0                              9.0
#
#     InadequatePlanning + WetlandLoss  \
# id
# 0                               12.0
# 1                                7.0
# 2                                5.0
# 3                               12.0
# 4                                5.0
#
#     IneffectiveDisasterPreparedness + Landslides  \
# id
# 0                                            5.0
# 1                                            9.0
# 2                                           13.0
# 3                                           12.0
# 4                                           11.0
#
#     IneffectiveDisasterPreparedness + MonsoonIntensity  \
# id
# 0                                                 7.0
# 1                                                15.0
# 2                                                12.0
# 3                                                 8.0
# 4                                                10.0
#
#     IneffectiveDisasterPreparedness + PoliticalFactors  \
# id
# 0                                                 5.0
# 1                                                12.0
# 2                                                 9.0
# 3                                                10.0
# 4                                                10.0
#
#     IneffectiveDisasterPreparedness + PopulationScore  \
# id
# 0                                                 9.0
# 1                                                12.0
# 2                                                14.0
# 3                                                11.0
# 4                                                 6.0
#
#     IneffectiveDisasterPreparedness + RiverManagement  \
# id
# 0                                                 7.0
# 1                                                13.0
# 2                                                12.0
# 3                                                11.0
# 4                                                 7.0
#
#     IneffectiveDisasterPreparedness + Siltation  \
# id
# 0                                           5.0
# 1                                          14.0
# 2                                          11.0
# 3                                          12.0
# 4                                           8.0
#
#     IneffectiveDisasterPreparedness + TopographyDrainage  \
# id
# 0                                                10.0
# 1                                                16.0
# 2                                                11.0
# 3                                                 9.0
# 4                                                 8.0
#
#     IneffectiveDisasterPreparedness + Urbanization  \
# id
# 0                                              8.0
# 1                                             17.0
# 2                                              9.0
# 3                                              9.0
# 4                                              9.0
#
#     IneffectiveDisasterPreparedness + Watersheds  \
# id
# 0                                            7.0
# 1                                           12.0
# 2                                           11.0
# 3                                            9.0
# 4                                           11.0
#
#     IneffectiveDisasterPreparedness + WetlandLoss  \
# id
# 0                                             7.0
# 1                                            12.0
# 2                                             8.0
# 3                                            10.0
# 4                                             7.0
#
#     Landslides + MonsoonIntensity  Landslides + PoliticalFactors  \
# id
# 0                             8.0                            6.0
# 1                             6.0                            3.0
# 2                            13.0                           10.0
# 3                            10.0                           12.0
# 4                            11.0                           11.0
#
#     Landslides + PopulationScore  Landslides + RiverManagement  \
# id
# 0                           10.0                           8.0
# 1                            3.0                           4.0
# 2                           15.0                          13.0
# 3                           13.0                          13.0
# 4                            7.0                           8.0
#
#     Landslides + Siltation  Landslides + TopographyDrainage  \
# id
# 0                      6.0                             11.0
# 1                      5.0                              7.0
# 2                     12.0                             12.0
# 3                     14.0                             11.0
# 4                      9.0                              9.0
#
#     Landslides + Urbanization  Landslides + Watersheds  \
# id
# 0                         9.0                      8.0
# 1                         8.0                      3.0
# 2                        10.0                     12.0
# 3                        11.0                     11.0
# 4                        10.0                     12.0
#
#     Landslides + WetlandLoss  MonsoonIntensity + PoliticalFactors  \
# id
# 0                        8.0                                  8.0
# 1                        3.0                                  9.0
# 2                        9.0                                  9.0
# 3                       12.0                                  8.0
# 4                        8.0                                 10.0
#
#     MonsoonIntensity + PopulationScore  MonsoonIntensity + RiverManagement  \
# id
# 0                                 12.0                                10.0
# 1                                  9.0                                10.0
# 2                                 14.0                                12.0
# 3                                  9.0                                 9.0
# 4                                  6.0                                 7.0
#
#     MonsoonIntensity + Siltation  MonsoonIntensity + TopographyDrainage  \
# id
# 0                            8.0                                   13.0
# 1                           11.0                                   13.0
# 2                           11.0                                   11.0
# 3                           10.0                                    7.0
# 4                            8.0                                    8.0
#
#     MonsoonIntensity + Urbanization  MonsoonIntensity + Watersheds  \
# id
# 0                              11.0                           10.0
# 1                              14.0                            9.0
# 2                               9.0                           11.0
# 3                               7.0                            7.0
# 4                               9.0                           11.0
#
#     MonsoonIntensity + WetlandLoss  PoliticalFactors + PopulationScore  \
# id
# 0                             10.0                                10.0
# 1                              9.0                                 6.0
# 2                              8.0                                11.0
# 3                              8.0                                11.0
# 4                              7.0                                 6.0
#
#     PoliticalFactors + RiverManagement  PoliticalFactors + Siltation  \
# id
# 0                                  8.0                           6.0
# 1                                  7.0                           8.0
# 2                                  9.0                           8.0
# 3                                 11.0                          12.0
# 4                                  7.0                           8.0
#
#     PoliticalFactors + TopographyDrainage  PoliticalFactors + Urbanization  \
# id
# 0                                    11.0                              9.0
# 1                                    10.0                             11.0
# 2                                     8.0                              6.0
# 3                                     9.0                              9.0
# 4                                     8.0                              9.0
#
#     PoliticalFactors + Watersheds  PoliticalFactors + WetlandLoss  \
# id
# 0                             8.0                             8.0
# 1                             6.0                             6.0
# 2                             8.0                             5.0
# 3                             9.0                            10.0
# 4                            11.0                             7.0
#
#     PopulationScore + RiverManagement  PopulationScore + Siltation  \
# id
# 0                                12.0                         10.0
# 1                                 7.0                          8.0
# 2                                14.0                         13.0
# 3                                12.0                         13.0
# 4                                 3.0                          4.0
#
#     PopulationScore + TopographyDrainage  PopulationScore + Urbanization  \
# id
# 0                                   15.0                            13.0
# 1                                   10.0                            11.0
# 2                                   13.0                            11.0
# 3                                   10.0                            10.0
# 4                                    4.0                             5.0
#
#     PopulationScore + Watersheds  PopulationScore + WetlandLoss  \
# id
# 0                           12.0                           12.0
# 1                            6.0                            6.0
# 2                           13.0                           10.0
# 3                           10.0                           11.0
# 4                            7.0                            3.0
#
#     RiverManagement + Siltation  RiverManagement + TopographyDrainage  \
# id
# 0                           8.0                                  13.0
# 1                           9.0                                  11.0
# 2                          11.0                                  11.0
# 3                          13.0                                  10.0
# 4                           5.0                                   5.0
#
#     RiverManagement + Urbanization  RiverManagement + Watersheds  \
# id
# 0                             11.0                          10.0
# 1                             12.0                           7.0
# 2                              9.0                          11.0
# 3                             10.0                          10.0
# 4                              6.0                           8.0
#
#     RiverManagement + WetlandLoss  Siltation + TopographyDrainage  \
# id
# 0                            10.0                            11.0
# 1                             7.0                            12.0
# 2                             8.0                            10.0
# 3                            11.0                            11.0
# 4                             4.0                             6.0
#
#     Siltation + Urbanization  Siltation + Watersheds  Siltation + WetlandLoss  \
# id
# 0                        9.0                     8.0                      8.0
# 1                       13.0                     8.0                      8.0
# 2                        8.0                    10.0                      7.0
# 3                       11.0                    11.0                     12.0
# 4                        7.0                     9.0                      5.0
#
#     TopographyDrainage + Urbanization  TopographyDrainage + Watersheds  \
# id
# 0                                14.0                             13.0
# 1                                15.0                             10.0
# 2                                 8.0                             10.0
# 3                                 8.0                              8.0
# 4                                 7.0                              9.0
#
#     TopographyDrainage + WetlandLoss  Urbanization + Watersheds  \
# id
# 0                               13.0                       11.0
# 1                               10.0                       11.0
# 2                                7.0                        8.0
# 3                                9.0                        8.0
# 4                                5.0                       10.0
#
#     Urbanization + WetlandLoss  Watersheds + WetlandLoss
# id
# 0                         11.0                      10.0
# 1                         11.0                       6.0
# 2                          5.0                       7.0
# 3                          9.0                       9.0
# 4                          6.0                       8.0

# %%
feature_matrix.shape
# Out:
# (1863262, 210)

# %%
train = feature_matrix.iloc[:train.shape[0], :]
train[TARGET] = labels

test = feature_matrix.iloc[train.shape[0]:, :]

del(composite)
del(labels)
_ = gc.collect()

# %%
train = reduce_memory_usage(train)
test = reduce_memory_usage(test)

_ = gc.collect()
# Out:
# Memory usage of dataframe is 1801.8220233917236 MB
# Memory usage of dataframe after reduction 437.12841987609863 MB
# Reduced by 75.7396449704142 %
# Memory usage of dataframe is 1199.7936630249023 MB
# Memory usage of dataframe after reduction 289.99752044677734 MB
# Reduced by 75.82938388625593 %

# %%
train['FloodLabel'] = (train['FloodProbability'] >= 0.5).astype('int8')
CAT_TARGET = 'FloodLabel'

# %%
gen_features = list(test.columns)

# %%
def comp_metric(y_true, y_pred):
    return r2_score(y_true, y_pred)

# %%
def custom_cv(task, feature_set, estimator, folds=10, seed=SEED, verbose=True):
    oof_preds, test_preds = {}, {}
    scores = []
    
    if task == 'clf':
        task_target = CAT_TARGET
    elif task == 'reg':
        task_target = TARGET
    else:
        print('Invalid task.')
        return

    cv = StratifiedKFold(n_splits=folds, shuffle=True, random_state=seed)
    for fold, (train_ids, val_ids) in enumerate(cv.split(train, train[CAT_TARGET])):
        X_train, y_train = train[feature_set].iloc[train_ids], train[task_target].iloc[train_ids]
        X_val, y_val = train[feature_set].iloc[val_ids], train[TARGET].iloc[val_ids]
        
        model = clone(estimator)
        model.fit(
            X_train, y_train,
            eval_set=[(X_val, y_val)],
            verbose=0)

        if task == 'clf':
            val_preds = model.predict_proba(X_val)[:, 1]
            oof_preds.update(dict(zip(val_ids, val_preds)))
            test_preds[f'fold{fold}'] = model.predict_proba(test[feature_set])[:, 1]
        else:  # 'reg'
            val_preds = model.predict(X_val)
            oof_preds.update(dict(zip(val_ids, val_preds)))
            test_preds[f'fold{fold}'] = model.predict(test[feature_set])

        score = comp_metric(y_val, val_preds)
        scores.append(score)
        if verbose:
            print(f'Fold #{fold:>2}: {score:.5f} ({model.best_iteration:>5} rounds)')
        _ = gc.collect()

    test_preds = pd.DataFrame.from_dict(test_preds)
    test_preds['mean'] = test_preds.mean(axis=1)  # mean of fold-wise predictions
    
    oof_preds = pd.Series(oof_preds).sort_index()
    print(f'\nAvg score: {np.mean(scores):.5f} +/- {np.std(scores):.5f}')
    print(f'OOF score: {comp_metric(train[TARGET], oof_preds):.5f}\n')
    
    return oof_preds, test_preds

# %%
op, tp = {}, {}

# %%
BASE_PARAMS = {
    'base_score': 0.5,
    'booster': 'gbtree',
    'tree_method': 'hist',
    'n_estimators': 25000,
    'early_stopping_rounds': 200,
    'device': DEVICE,
    'enable_categorical': True,
    'verbosity': 0,
    'n_jobs': -1,
    'seed': SEED
}

# %%
reg_model1 = xgb.XGBRegressor(
    **BASE_PARAMS, 
    learning_rate=0.1,
    alpha=10,
    objective='reg:squarederror', 
    eval_metric='rmse')

op['cfg1'], tp['cfg1'] = custom_cv(
    task='reg',
    feature_set=gen_features,
    estimator=reg_model1)
# Out:
# Fold # 0: 0.83528 ( 1744 rounds)
# Fold # 1: 0.83721 ( 1857 rounds)
# Fold # 2: 0.83576 ( 1831 rounds)
# Fold # 3: 0.83657 ( 1885 rounds)
# Fold # 4: 0.83872 ( 1866 rounds)
# Fold # 5: 0.83709 ( 1800 rounds)
# Fold # 6: 0.83658 ( 1837 rounds)
# Fold # 7: 0.83717 ( 1777 rounds)
# Fold # 8: 0.83606 ( 1847 rounds)
# Fold # 9: 0.83567 ( 1869 rounds)
#
# Avg score: 0.83661 +/- 0.00095
# OOF score: 0.83661

# %%
reg_model2 = xgb.XGBRegressor(
    **BASE_PARAMS, 
    objective='reg:tweedie',
    learning_rate=0.01,
    tweedie_variance_power=1.5,
    eval_metric='rmse')

op['cfg2'], tp['cfg2'] = custom_cv(
    task='reg',
    feature_set=gen_features,
    estimator=reg_model2)
# Out:
# Fold # 0: 0.84492 (17316 rounds)
# Fold # 1: 0.84669 (16359 rounds)
# Fold # 2: 0.84562 (17077 rounds)
# Fold # 3: 0.84633 (16306 rounds)
# Fold # 4: 0.84810 (16564 rounds)
# Fold # 5: 0.84691 (15142 rounds)
# Fold # 6: 0.84674 (16638 rounds)
# Fold # 7: 0.84686 (16154 rounds)
# Fold # 8: 0.84577 (17084 rounds)
# Fold # 9: 0.84582 (18406 rounds)
#
# Avg score: 0.84638 +/- 0.00084
# OOF score: 0.84638
